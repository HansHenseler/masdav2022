# %% [markdown]
# <a href="https://colab.research.google.com/github/HansHenseler/masdav2022/blob/main/Part_4_Elasticsearch_and_log2timeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Opensearch and log2timeline
#
# Exercise 4:
#
# Master of Advanced Studies in Digital Forensics & Cyber Investigation
#
# Data Analytics and Visualization for Digital Forensics
#
# (c) Hans Henseler, 2022

# %% [markdown]
# ## 1 Installing plaso tools in the colab notebook
#
# First install Plaso-tools as we did in exercise 3

# %%
# various install steps to install plaso tools and dependencies to get plaso working in colab
# -y option is to skip user interaction
# some packages need to be deinstalled and reinstalled to resolve dependencies
# these steps take app. 3 minutes to complete on a fresh colab instance
# !add-apt-repository -y ppa:gift/stable
# !apt update
# !apt-get update
# !apt install plaso-tools
# !pip uninstall -y pytsk3
# !pip install pytsk3
# !pip uninstall -y yara-python
# !pip install yara-python
# !pip uninstall -y lz4
# !pip install lz4

# %%
# This notebook was tested with version 20220724 (psort.py assumes opensearch and longer elasticsearch)

# !psort.py -V
# Out:
# plaso - psort version 20220724

# %%
# check if plaso tools were installed by running psort.py

# !psort.py -o list
# Out:
# ******************************** Output Modules ********************************
#          Name : Description
# --------------------------------------------------------------------------------
#       dynamic : Dynamic selection of fields for a separated value output
#                 format.
#          json : Saves the events into a JSON format.
#     json_line : Saves the events into a JSON line format.
#           kml : Saves events with geography data into a KML format.
#        l2tcsv : CSV format used by legacy log2timeline, with 17 fixed fields.
#        l2ttln : Extended TLN 7 field | delimited output.
#          null : Output module that does not output anything.
#    opensearch : Saves the events into an OpenSearch database.
# opensearch_ts : Saves the events into an OpenSearch database for use with
#                 Timesketch.
#         rawpy : native (or "raw") Python output.
#           tln : TLN 5 field | delimited output.
#          xlsx : Excel Spreadsheet (XLSX) output
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 2 Download and setup the Opensearch instance
#
# There are different was to install and use Opensearch. Because we are working in a notebook we will download and install using a tar-ball which can be downloaded from: https://opensearch.org/downloads.html .

# %%
# !wget -q https://artifacts.opensearch.org/releases/bundle/opensearch/2.2.0/opensearch-2.2.0-linux-x64.tar.gz
# !wget -q https://artifacts.opensearch.org/releases/bundle/opensearch/2.2.0/opensearch-2.2.0-linux-x64.tar.gz.sha512
# !tar -zxf opensearch-2.2.0-linux-x64.tar.gz
# !shasum -a 512 -c opensearch-2.2.0-linux-x64.tar.gz.sha512
# Out:
# opensearch-2.2.0-linux-x64.tar.gz: OK

# %%
# change the owner of the Opensearch filetree from root to daemon because Opensearch cannot run as root.

# !sudo chown -R daemon:daemon opensearch-2.2.0/

# %% [markdown]
# Run Elasticsearch as a daemon process

# %%
# start Opensearch from the commandline as user daemon. 

# !sudo -H -u daemon sh -c  "opensearch-2.2.0/opensearch-tar-install.sh 1> /content/opensearch-2.2.0/logs/os.log 2> /content/opensearch-2.2.0/logs/os.err &"

# %%
# Sleep for few seconds to let the instance start.
import time
time.sleep(20)

# %% [markdown]
# Once the instance has been started, grep for elasticsearch in the processes list to confirm the availability.

# %%
# !ps -ef | grep opensearch
# Out:
# daemon      7868       1 86 21:05 ?        00:00:42 /content/opensearch-2.2.0/jdk/bin/java -Xshare:auto -Dopensearch.networkaddress.cache.ttl=60 -Dopensearch.networkaddress.cache.negative.ttl=10 -XX:+AlwaysPreTouch -Xss1m -Djava.awt.headless=true -Dfile.encoding=UTF-8 -Djna.nosys=true -XX:-OmitStackTraceInFastThrow -XX:+ShowCodeDetailsInExceptionMessages -Dio.netty.noUnsafe=true -Dio.netty.noKeySetOptimization=true -Dio.netty.recycler.maxCapacityPerThread=0 -Dio.netty.allocator.numDirectArenas=0 -Dlog4j.shutdownHookEnabled=false -Dlog4j2.disable.jmx=true -Djava.locale.providers=SPI,COMPAT -Xms1g -Xmx1g -XX:+UseG1GC -XX:G1ReservePercent=25 -XX:InitiatingHeapOccupancyPercent=30 -Djava.io.tmpdir=/tmp/opensearch-6940095575402420919 -XX:+HeapDumpOnOutOfMemoryError -XX:HeapDumpPath=data -XX:ErrorFile=logs/hs_err_pid%p.log -Xlog:gc*,gc+age=trace,safepoint:file=logs/gc.log:utctime,pid,tags:filecount=32,filesize=64m -Dclk.tck=100 -Djdk.attach.allowAttachSelf=true -Djava.security.policy=/content/opensearch-2.2.0/config/opensearch-performance-analyzer/opensearch_security.policy --add-opens=jdk.attach/sun.tools.attach=ALL-UNNAMED -XX:MaxDirectMemorySize=536870912 -Dopensearch.path.home=/content/opensearch-2.2.0 -Dopensearch.path.conf=/content/opensearch-2.2.0/config -Dopensearch.distribution.type=tar -Dopensearch.bundled_jdk=true -cp /content/opensearch-2.2.0/lib/* org.opensearch.bootstrap.OpenSearch
# root        8233      60  0 21:06 ?        00:00:00 /bin/bash -c ps -ef | grep opensearch
# root        8235    8233  0 21:06 ?        00:00:00 grep opensearch

# %% [markdown]
# Query the base endpoint at localhost port 9200 to retrieve information about the cluster. Opensearch requires https, username and password.

# %%
# !curl -XGET https://localhost:9200 -u 'admin:admin' --insecure
# Out:
# {
#   "name" : "a60adf93bf0b",
#   "cluster_name" : "opensearch",
#   "cluster_uuid" : "dgyuJXYETfKoTk-6wL_G-w",
#   "version" : {
#     "distribution" : "opensearch",
#     "number" : "2.2.0",
#     "build_type" : "tar",
#     "build_hash" : "b1017fa3b9a1c781d4f34ecee411e0cdf930a515",
#     "build_date" : "2022-08-09T02:27:25.256769336Z",
#     "build_snapshot" : false,
#     "lucene_version" : "9.3.0",
#     "minimum_wire_compatibility_version" : "7.10.0",
#     "minimum_index_compatibility_version" : "7.0.0"
#   },
#   "tagline" : "The OpenSearch Project: https://opensearch.org/"
# }

# %%
# After installation there is only one index that is the  .opendistro_security index that is used for internal purposes

# !curl -XGET "https://localhost:9200/_cat/indices?v" -u 'admin:admin' --insecure
# Out:
# health status index                uuid                   pri rep docs.count docs.deleted store.size pri.store.size
# green  open   .opendistro_security a2dJDoODRAWjjqnKuWByyA   1   0         10            0     69.1kb         69.1kb

# %% [markdown]
# ## 3 Use Log2timeline.py and Psort.py to load data in Elasticsearch

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# In part 3 (step 3) we stored the mus2019ctf.plaso file in your drive. 
#
plaso_file = 'gdrive/MyDrive/mus2019ctf.plaso'
#
# and check if it's there
#
# !ls -l $plaso_file
# Out:
# -rw------- 1 root root 403488768 Aug 15 15:17 gdrive/MyDrive/mus2019ctf.plaso

# %%
# If it's not there you can create it by repeating the following steps
# 
# The complete mus2019ctf.plaso file is 450MB and takes a while. After you have created it
# it makes sense to store it in your gdrive so you can reuse it:
#
#plaso_file = 'gdrive/MyDrive/Colab\ Notebooks/Data\ Analytics\ and\ Visualisation\ Course/mus2019ctf.plaso'
#
# if not you need to create it with log2timeline.py using the complete windows_filter.txt filter
#
# add a shortcut in your Google drive to this shared drive https://drive.google.com/drive/folders/1KUlZUl4Sy2JzgbuRW-oHjIGFClY2bl75?usp=sharing
# then mount you google drive in this colab (you need to authorize this colab to access your google drive)
#
#disk_image = "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01"
#plaso_gdrive_folder = 'gdrive/MyDrive'
#!wget "https://raw.githubusercontent.com/mark-hallman/plaso_filters/master/filter_windows.txt"
#!log2timeline.py -f filter_windows.txt --storage-file mus2019ctf.plaso $disk_image 
#!ls -l $disk_image
#!cp mus2019ctf.plaso $plaso_gdrive_folder
#plaso_file = 'gdrive/MyDrive/mus2019ctf.plaso'
#!ls -l $plaso_file
# Out:
# -r-------- 1 root root 10616142693 Mar 21  2019 /content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01
# -rw------- 1 root root 403488768 Aug 15 15:17 gdrive/MyDrive/mus2019ctf.plaso

# %% [markdown]
# Use psort to write events to Elasticsearch that we setup earlier. We can use the elastic output format

# %%
# Before we do that, let's take a look at the opensearch.mappings file that comes with plaso
# actually there is more in that folder that you may be interested in
#
# !ls /usr/share/plaso
# Out:
# filter_no_winsxs.yaml  opensearch.mappings  sources.config   winevt-rc.db
# filter_windows.txt     plaso-data.README    tag_linux.txt
# filter_windows.yaml    presets.yaml	    tag_macos.txt
# formatters	       signatures.conf	    tag_windows.txt

# %%
# let's take a look at the opensearch.mappings
#
# !cat /usr/share/plaso/opensearch.mappings
# Out:
# {
#   "properties": {
#     "application": {
#       "type": "text",
#       "fields": {
#         "keyword": {"type": "keyword"}}
#     },
#     "data": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "doc_type": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "event_type": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "exit_status": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "facility": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "file_reference": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "file_size": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "flags": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "identifier": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "message_status": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "message_type": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "offset": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "sequence_number": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "severity": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "source_port": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "user_identifier": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     },
#     "version": {
#       "type": "text",
#       "fields": {"keyword": {"type": "keyword"}}
#     }
#   }
# }

# %%
# Field file_size has type text. 
#
#    "file_size": {
#      "type": "text",
#      "fields": {"keyword": {"type": "keyword"}}
#    },
#
# Let's change the mapping for file_size to type long
#
#
#    "file_size": {
#      "type": "long"
#    },

# %%
# run psort.py. It takes about 13 minutes to export all rows from the 385MB plaso file to Opensearch

#
# !psort.py -o opensearch --server localhost --port 9200 --opensearch-user admin --opensearch-password admin --opensearch_mappings /usr/share/plaso/opensearch.mappings --use_ssl --ca_certificates_file_path /content/opensearch-2.2.0/config/root-ca.pem --index_name newmus2019ctf $plaso_file --status_view none
# Out:
# 2022-08-16 10:13:27,408 [INFO] (MainProcess) PID:13001 <data_location> Determined data location: /usr/share/plaso
# 2022-08-16 10:13:27,790 [WARNING] (MainProcess) PID:13001 <opensearch_output> Note that specifying your OpenSearch password via --opensearch_password or the environment PLASO_OPENSEARCH_PASSWORD can expose the password to other users on the system.
# Processing completed.

# %%
# Let's take a look again at the indices in our Elasticsearch instance
#
#!curl -X GET "https://localhost:9200/_cat/indices?format=json&pretty" -u admin:admin --insecure
# !curl -X GET "https://localhost:9200/_cat/indices?v" -u admin:admin --insecure
# Out:
# health status index                        uuid                   pri rep docs.count docs.deleted store.size pri.store.size
# yellow open   security-auditlog-2022.08.16 DJB4b0LsTrGQcIazwR28sQ   1   1         40            0    168.8kb        168.8kb
# yellow open   newmus2019ctf                PYOaJzhMSW616S5gCN6nGg   1   1     805010            0    377.5mb        377.5mb
# green  open   .opendistro_security         a2dJDoODRAWjjqnKuWByyA   1   0         10            0     69.1kb         69.1kb

# %%
# we can also see what fields were mapped in this index by Psort.py
#
# !curl -XGET "https://localhost:9200/newmus2019ctf/_mapping?format=json&pretty" -u admin:admin --insecure
# Out:
# {
#   "newmus2019ctf" : {
#     "mappings" : {
#       "properties" : {
#         "access_count" : {
#           "type" : "long"
#         },
#         "account_rid" : {
#           "type" : "long"
#         },
#         "application" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "binary_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "birth_droid_file_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "birth_droid_volume_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "build_number" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "cache_identifier" : {
#           "type" : "long"
#         },
#         "cached_file_size" : {
#           "type" : "long"
#         },
#         "cached_filename" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "command" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "comments" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "company_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "computer_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "configuration" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "connection_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "container_identifier" : {
#           "type" : "long"
#         },
#         "data" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "data_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "datetime" : {
#           "type" : "date"
#         },
#         "default_gateway_mac" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "description" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "device_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "directory" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "display_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "dll_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "dns_suffix" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "doc_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "drive_serial_number" : {
#           "type" : "long"
#         },
#         "drive_type" : {
#           "type" : "long"
#         },
#         "droid_file_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "droid_volume_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "entries" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "entry_identifier" : {
#           "type" : "long"
#         },
#         "entry_index" : {
#           "type" : "long"
#         },
#         "entry_number" : {
#           "type" : "long"
#         },
#         "entry_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "error_control" : {
#           "type" : "long"
#         },
#         "event_identifier" : {
#           "type" : "long"
#         },
#         "event_level" : {
#           "type" : "long"
#         },
#         "event_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "executable" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "exit_status" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "facility" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "file_attribute_flags" : {
#           "type" : "long"
#         },
#         "file_entry_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "file_reference" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "file_size" : {
#           "type" : "long"
#         },
#         "file_system_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "file_version" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "filename" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "flags" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "full_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "fullname" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "hostname" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "icon_location" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "image_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "imphash" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "inode" : {
#           "type" : "long"
#         },
#         "is_allocated" : {
#           "type" : "boolean"
#         },
#         "key_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "link_target" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "local_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "localized_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "login_count" : {
#           "type" : "long"
#         },
#         "long_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "mac_address" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "mapped_files" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "message" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "message_identifier" : {
#           "type" : "long"
#         },
#         "message_status" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "message_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "network_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "number_of_volumes" : {
#           "type" : "long"
#         },
#         "object_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "offset" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "origin" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "owner" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "parent_file_reference" : {
#           "type" : "long"
#         },
#         "parser" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "partition_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "partition_type" : {
#           "type" : "long"
#         },
#         "path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "path_hints" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "path_spec" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "pe_attribute" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "pe_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "pin_status" : {
#           "type" : "long"
#         },
#         "prefetch_hash" : {
#           "type" : "long"
#         },
#         "product" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "product_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "program_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "provider_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "record_number" : {
#           "type" : "long"
#         },
#         "recovered" : {
#           "type" : "boolean"
#         },
#         "relative_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "response_headers" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "run_count" : {
#           "type" : "long"
#         },
#         "section_names" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "sequence_number" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "serial" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "serial_number" : {
#           "type" : "long"
#         },
#         "service_dll" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "service_type" : {
#           "type" : "long"
#         },
#         "set_identifier" : {
#           "type" : "long"
#         },
#         "settings" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "severity" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "sha256_hash" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "shell_item_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "size" : {
#           "type" : "long"
#         },
#         "source_long" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "source_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "source_port" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "source_short" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "ssid" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "start_type" : {
#           "type" : "long"
#         },
#         "strings" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "subkey_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "sync_count" : {
#           "type" : "long"
#         },
#         "table_identifier" : {
#           "type" : "long"
#         },
#         "task_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "task_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "timestamp" : {
#           "type" : "long"
#         },
#         "timestamp_desc" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "trigger" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "update_reason_flags" : {
#           "type" : "long"
#         },
#         "update_sequence_number" : {
#           "type" : "long"
#         },
#         "update_source_flags" : {
#           "type" : "long"
#         },
#         "url" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "user_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "user_sid" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "username" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "uuid" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "value" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "value_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "values" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "vendor" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "version" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "volume_device_paths" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "volume_label" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "volume_serial_numbers" : {
#           "type" : "long"
#         },
#         "working_directory" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "xml_string" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# ## 4 Accessing Elasticsearch via the REST API

# %%
# we can use the elastic search api to get the first 10 results
#
# !curl -sX GET "https://localhost:9200/_search?format=json&pretty" -u admin:admin --insecure
# Out:
# {
#   "took" : 183,
#   "timed_out" : false,
#   "_shards" : {
#     "total" : 3,
#     "successful" : 3,
#     "skipped" : 0,
#     "failed" : 0
#   },
#   "hits" : {
#     "total" : {
#       "value" : 10000,
#       "relation" : "gte"
#     },
#     "max_score" : 1.0,
#     "hits" : [
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "nEckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "imphash" : "ee7cb4a1dbc04570233ef522c5ab5b76",
#           "pe_type" : "Dynamic Link Library (DLL)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99903, \"mft_attribute\": 2, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\adfs_globals.dll\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "fcb268fb1a1019f3698b28402e9ae796adac7684eef4c5d40278b156ce9292b5",
#           "datetime" : "2012-08-23T20:12:50.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\adfs_globals.dll",
#           "message" : "PE Type: Dynamic Link Library (DLL) Import hash: ee7cb4a1dbc04570233ef522c5ab5b76",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752770000000,
#           "timestamp_desc" : "Creation Time"
#         }
#       },
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "nUckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "dll_name" : "adefs.dll",
#           "imphash" : "0adf7f91b6f62323009c96271d92ea3a",
#           "pe_attribute" : "DIRECTORY_ENTRY_EXPORT",
#           "pe_type" : "Dynamic Link Library (DLL)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99849, \"mft_attribute\": 1, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\adefs.dll\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "41127ab178d8c65f2fe1387214da8d9e360abdd7cb24bb0ddb684ec350b00c6b",
#           "datetime" : "2012-08-23T20:12:51.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\adefs.dll",
#           "message" : "PE Type: Dynamic Link Library (DLL) [DIRECTORY_ENTRY_EXPORT] DLL name: adefs.dll Import hash: 0adf7f91b6f62323009c96271d92ea3a",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752771000000,
#           "timestamp_desc" : "Content Modification Time"
#         }
#       },
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "nkckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "dll_name" : "adshattrdefs.dll",
#           "imphash" : "c211c3be83dc51ada056271b7277b091",
#           "pe_attribute" : "DIRECTORY_ENTRY_EXPORT",
#           "pe_type" : "Dynamic Link Library (DLL)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99905, \"mft_attribute\": 2, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\adshattrdefs.dll\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "6c3998249898d44b71909d3d3d4f10527658a268c24e0d92905f1739644410df",
#           "datetime" : "2012-08-23T20:12:51.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\adshattrdefs.dll",
#           "message" : "PE Type: Dynamic Link Library (DLL) [DIRECTORY_ENTRY_EXPORT] DLL name: adshattrdefs.dll Import hash: c211c3be83dc51ada056271b7277b091",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752771000000,
#           "timestamp_desc" : "Content Modification Time"
#         }
#       },
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "n0ckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "imphash" : "0adf7f91b6f62323009c96271d92ea3a",
#           "pe_type" : "Dynamic Link Library (DLL)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99849, \"mft_attribute\": 1, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\adefs.dll\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "41127ab178d8c65f2fe1387214da8d9e360abdd7cb24bb0ddb684ec350b00c6b",
#           "datetime" : "2012-08-23T20:12:51.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\adefs.dll",
#           "message" : "PE Type: Dynamic Link Library (DLL) Import hash: 0adf7f91b6f62323009c96271d92ea3a",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752771000000,
#           "timestamp_desc" : "Creation Time"
#         }
#       },
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "oEckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "dll_name" : "adencrypt.dll",
#           "imphash" : "7633ca0edc7132c904d20211abaa197f",
#           "pe_attribute" : "DIRECTORY_ENTRY_EXPORT",
#           "pe_type" : "Dynamic Link Library (DLL)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99852, \"mft_attribute\": 2, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\adencrypt.dll\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "b80486efc4a4a4f87f06f912ad77d95bb3dd40ba5cb37b40f6d7ffb1c7723618",
#           "datetime" : "2012-08-23T20:12:53.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\adencrypt.dll",
#           "message" : "PE Type: Dynamic Link Library (DLL) [DIRECTORY_ENTRY_EXPORT] DLL name: adencrypt.dll Import hash: 7633ca0edc7132c904d20211abaa197f",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752773000000,
#           "timestamp_desc" : "Content Modification Time"
#         }
#       },
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "oUckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "imphash" : "7633ca0edc7132c904d20211abaa197f",
#           "pe_type" : "Dynamic Link Library (DLL)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99852, \"mft_attribute\": 2, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\adencrypt.dll\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "b80486efc4a4a4f87f06f912ad77d95bb3dd40ba5cb37b40f6d7ffb1c7723618",
#           "datetime" : "2012-08-23T20:12:53.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\adencrypt.dll",
#           "message" : "PE Type: Dynamic Link Library (DLL) Import hash: 7633ca0edc7132c904d20211abaa197f",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752773000000,
#           "timestamp_desc" : "Creation Time"
#         }
#       },
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "okckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "dll_name" : "adencrypt_gui.exe",
#           "imphash" : "db7d21d8ad5e600e27c71dd8e66d69fe",
#           "pe_attribute" : "DIRECTORY_ENTRY_EXPORT",
#           "pe_type" : "Executable (EXE)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99901, \"mft_attribute\": 2, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\adencrypt_gui.exe\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "cd44d98f5051c60455d8e8583d66e306b79dafd1dc4af2dafd7328d98319df6e",
#           "datetime" : "2012-08-23T20:12:57.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\adencrypt_gui.exe",
#           "message" : "PE Type: Executable (EXE) [DIRECTORY_ENTRY_EXPORT] DLL name: adencrypt_gui.exe Import hash: db7d21d8ad5e600e27c71dd8e66d69fe",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752777000000,
#           "timestamp_desc" : "Content Modification Time"
#         }
#       },
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "o0ckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "imphash" : "db7d21d8ad5e600e27c71dd8e66d69fe",
#           "pe_type" : "Executable (EXE)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99901, \"mft_attribute\": 2, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\adencrypt_gui.exe\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "cd44d98f5051c60455d8e8583d66e306b79dafd1dc4af2dafd7328d98319df6e",
#           "datetime" : "2012-08-23T20:12:57.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\adencrypt_gui.exe",
#           "message" : "PE Type: Executable (EXE) Import hash: db7d21d8ad5e600e27c71dd8e66d69fe",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752777000000,
#           "timestamp_desc" : "Creation Time"
#         }
#       },
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "pEckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "imphash" : "c211c3be83dc51ada056271b7277b091",
#           "pe_type" : "Dynamic Link Library (DLL)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99905, \"mft_attribute\": 2, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\adshattrdefs.dll\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "6c3998249898d44b71909d3d3d4f10527658a268c24e0d92905f1739644410df",
#           "datetime" : "2012-08-23T20:13:04.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\adshattrdefs.dll",
#           "message" : "PE Type: Dynamic Link Library (DLL) Import hash: c211c3be83dc51ada056271b7277b091",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752784000000,
#           "timestamp_desc" : "Creation Time"
#         }
#       },
#       {
#         "_index" : "newmus2019ctf",
#         "_id" : "pUckpoIBNwEKF-Xi8i4u",
#         "_score" : 1.0,
#         "_source" : {
#           "data_type" : "pe",
#           "parser" : "pe",
#           "dll_name" : "LMS.dll",
#           "imphash" : "b63b0b1461a54283891f537d52adf41f",
#           "pe_attribute" : "DIRECTORY_ENTRY_EXPORT",
#           "pe_type" : "Dynamic Link Library (DLL)",
#           "section_names" : [
#             ".text\u0000\u0000\u0000",
#             ".rdata\u0000\u0000",
#             ".data\u0000\u0000\u0000",
#             ".rsrc\u0000\u0000\u0000",
#             ".reloc\u0000\u0000"
#           ],
#           "path_spec" : "{\"__type__\": \"PathSpec\", \"mft_entry\": 99922, \"mft_attribute\": 1, \"location\": \"\\\\Users\\\\Administrator\\\\Desktop\\\\FTK_Imager_Lite_3.1.1\\\\LMS.dll\", \"parent\": {\"__type__\": \"PathSpec\", \"part_index\": 2, \"start_offset\": 576716800, \"location\": \"/p1\", \"parent\": {\"__type__\": \"PathSpec\", \"parent\": {\"__type__\": \"PathSpec\", \"location\": \"/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01\", \"type_indicator\": \"OS\"}, \"type_indicator\": \"EWF\"}, \"type_indicator\": \"TSK_PARTITION\"}, \"type_indicator\": \"NTFS\"}",
#           "sha256_hash" : "d16e0fefdad3fa199ee3267c9885edd40cb5f420e8f7ec7f400f47b891c1aa75",
#           "datetime" : "2012-08-23T20:13:10.000000+00:00",
#           "display_name" : "NTFS:\\Users\\Administrator\\Desktop\\FTK_Imager_Lite_3.1.1\\LMS.dll",
#           "message" : "PE Type: Dynamic Link Library (DLL) [DIRECTORY_ENTRY_EXPORT] DLL name: LMS.dll Import hash: b63b0b1461a54283891f537d52adf41f",
#           "source_long" : "PE Event",
#           "source_short" : "PE",
#           "tag" : [ ],
#           "timestamp" : 1345752790000000,
#           "timestamp_desc" : "Content Modification Time"
#         }
#       }
#     ]
#   }
# }

# %%
# show the settings for the newmus2019ctf index

# !curl -sX GET "https://localhost:9200/newmus2019ctf/_settings?format=json&pretty" -u admin:admin --insecure
# Out:
# {
#   "newmus2019ctf" : {
#     "settings" : {
#       "index" : {
#         "creation_date" : "1660644810956",
#         "number_of_shards" : "1",
#         "number_of_replicas" : "1",
#         "uuid" : "PYOaJzhMSW616S5gCN6nGg",
#         "version" : {
#           "created" : "136237827"
#         },
#         "provided_name" : "newmus2019ctf"
#       }
#     }
#   }
# }

# %% [markdown]
# ## 5 Accessing the Opensearch API in Python

# %%
# So far we have been accessing information directly with curl from the Opensearch REST API
# The is also an Opensearch Python API that we can use. See https://opensearch.org/docs/latest/clients/python/
#

from opensearchpy import OpenSearch

host = 'localhost'
port = 9200
auth = ('admin', 'admin') # For testing only. Don't store credentials in code.
ca_certs_path = '/content/opensearch-2.2.0/config/root-ca.pem' # Provide a CA bundle if you use intermediate CAs with your root CA.

# Create the client with SSL/TLS enabled, but hostname verification disabled.
client = OpenSearch(
    hosts = [{'host': 'localhost', 'port': 9200}],
    http_compress = True, # enables gzip compression for request bodies
    http_auth = auth,
    use_ssl = True,
    verify_certs = True,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
    ca_certs = ca_certs_path
)

# %% [markdown]
# Which indexes are available?

# %%
client.indices.get_alias("*")
# Out:
# {'security-auditlog-2022.08.16': {'aliases': {}},
#  'newmus2019ctf': {'aliases': {}},
#  '.opendistro_security': {'aliases': {}}}

# %% [markdown]
# Search the index with a full-text query and get the first 5 results

# %%
response = client.search(index="newmus2019ctf", body={"query": {"match": {"message": { "query": "selmabouvier"  }}}}, size=5)
docs = response['hits']['hits']
docs
# Out:
# [{'_index': 'newmus2019ctf',
#   '_id': 'jUwppoIBNwEKF-XieZor',
#   '_score': 7.8198056,
#   '_source': {'data_type': 'fs:stat',
#    'parser': 'filestat',
#    'display_name': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini',
#    'file_entry_type': 'file',
#    'file_size': 282,
#    'file_system_type': 'NTFS',
#    'filename': '\\Users\\SelmaBouvier\\Desktop\\desktop.ini',
#    'inode': 1125899906949326,
#    'is_allocated': True,
#    'path_spec': '{"__type__": "PathSpec", "mft_entry": 106702, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Desktop\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}',
#    'sha256_hash': '4b9d687ac625690fd026ed4b236dad1cac90ef69e7ad256cc42766a065b50026',
#    'datetime': '2019-02-25T20:47:01.374840+00:00',
#    'message': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini Type: file',
#    'source_long': 'File stat',
#    'source_short': 'FILE',
#    'tag': [],
#    'timestamp': 1551127621374840,
#    'timestamp_desc': 'Creation Time'}},
#  {'_index': 'newmus2019ctf',
#   '_id': 'kUwppoIBNwEKF-XieZor',
#   '_score': 7.8198056,
#   '_source': {'data_type': 'fs:stat',
#    'parser': 'filestat',
#    'display_name': 'NTFS:\\Users\\SelmaBouvier\\Documents\\desktop.ini',
#    'file_entry_type': 'file',
#    'file_size': 402,
#    'file_system_type': 'NTFS',
#    'filename': '\\Users\\SelmaBouvier\\Documents\\desktop.ini',
#    'inode': 844424930238702,
#    'is_allocated': True,
#    'path_spec': '{"__type__": "PathSpec", "mft_entry": 106734, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Documents\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}',
#    'sha256_hash': 'cafec240d998e4b6e92ad1329cd417e8e9cbd73157488889fd93a542de4a4844',
#    'datetime': '2019-02-25T20:47:01.483741+00:00',
#    'message': 'NTFS:\\Users\\SelmaBouvier\\Documents\\desktop.ini Type: file',
#    'source_long': 'File stat',
#    'source_short': 'FILE',
#    'tag': [],
#    'timestamp': 1551127621483741,
#    'timestamp_desc': 'Creation Time'}},
#  {'_index': 'newmus2019ctf',
#   '_id': 'lEwppoIBNwEKF-XieZor',
#   '_score': 7.8198056,
#   '_source': {'data_type': 'fs:stat',
#    'parser': 'filestat',
#    'display_name': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini',
#    'file_entry_type': 'file',
#    'file_size': 282,
#    'file_system_type': 'NTFS',
#    'filename': '\\Users\\SelmaBouvier\\Desktop\\desktop.ini',
#    'inode': 1125899906949326,
#    'is_allocated': True,
#    'path_spec': '{"__type__": "PathSpec", "mft_entry": 106702, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Desktop\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}',
#    'sha256_hash': '4b9d687ac625690fd026ed4b236dad1cac90ef69e7ad256cc42766a065b50026',
#    'datetime': '2019-02-25T20:47:01.626798+00:00',
#    'message': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini Type: file',
#    'source_long': 'File stat',
#    'source_short': 'FILE',
#    'tag': [],
#    'timestamp': 1551127621626798,
#    'timestamp_desc': 'Content Modification Time'}},
#  {'_index': 'newmus2019ctf',
#   '_id': 'lUwppoIBNwEKF-XieZor',
#   '_score': 7.8198056,
#   '_source': {'data_type': 'fs:stat',
#    'parser': 'filestat',
#    'display_name': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini',
#    'file_entry_type': 'file',
#    'file_size': 282,
#    'file_system_type': 'NTFS',
#    'filename': '\\Users\\SelmaBouvier\\Desktop\\desktop.ini',
#    'inode': 1125899906949326,
#    'is_allocated': True,
#    'path_spec': '{"__type__": "PathSpec", "mft_entry": 106702, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Desktop\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}',
#    'sha256_hash': '4b9d687ac625690fd026ed4b236dad1cac90ef69e7ad256cc42766a065b50026',
#    'datetime': '2019-02-25T20:47:01.626798+00:00',
#    'message': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini Type: file',
#    'source_long': 'File stat',
#    'source_short': 'FILE',
#    'tag': [],
#    'timestamp': 1551127621626798,
#    'timestamp_desc': 'Metadata Modification Time'}},
#  {'_index': 'newmus2019ctf',
#   '_id': 'lkwppoIBNwEKF-XieZor',
#   '_score': 7.8198056,
#   '_source': {'data_type': 'fs:stat',
#    'parser': 'filestat',
#    'display_name': 'NTFS:\\Users\\SelmaBouvier\\Downloads\\desktop.ini',
#    'file_entry_type': 'file',
#    'file_size': 282,
#    'file_system_type': 'NTFS',
#    'filename': '\\Users\\SelmaBouvier\\Downloads\\desktop.ini',
#    'inode': 844424930238731,
#    'is_allocated': True,
#    'path_spec': '{"__type__": "PathSpec", "mft_entry": 106763, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Downloads\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}',
#    'sha256_hash': 'b029393ea7b7cf644fb1c9f984f57c1980077562ee2e15d0ffd049c4c48098d3',
#    'datetime': '2019-02-25T20:47:01.651227+00:00',
#    'message': 'NTFS:\\Users\\SelmaBouvier\\Downloads\\desktop.ini Type: file',
#    'source_long': 'File stat',
#    'source_short': 'FILE',
#    'tag': [],
#    'timestamp': 1551127621651227,
#    'timestamp_desc': 'Creation Time'}}]

# %%
# The '_source' property has the psort values
#
for num, doc in enumerate(docs):
  print(num, '-->', doc['_source'], "\n")
# Out:
# 0 --> {'data_type': 'fs:stat', 'parser': 'filestat', 'display_name': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini', 'file_entry_type': 'file', 'file_size': 282, 'file_system_type': 'NTFS', 'filename': '\\Users\\SelmaBouvier\\Desktop\\desktop.ini', 'inode': 1125899906949326, 'is_allocated': True, 'path_spec': '{"__type__": "PathSpec", "mft_entry": 106702, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Desktop\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}', 'sha256_hash': '4b9d687ac625690fd026ed4b236dad1cac90ef69e7ad256cc42766a065b50026', 'datetime': '2019-02-25T20:47:01.374840+00:00', 'message': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini Type: file', 'source_long': 'File stat', 'source_short': 'FILE', 'tag': [], 'timestamp': 1551127621374840, 'timestamp_desc': 'Creation Time'}
#
# 1 --> {'data_type': 'fs:stat', 'parser': 'filestat', 'display_name': 'NTFS:\\Users\\SelmaBouvier\\Documents\\desktop.ini', 'file_entry_type': 'file', 'file_size': 402, 'file_system_type': 'NTFS', 'filename': '\\Users\\SelmaBouvier\\Documents\\desktop.ini', 'inode': 844424930238702, 'is_allocated': True, 'path_spec': '{"__type__": "PathSpec", "mft_entry": 106734, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Documents\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}', 'sha256_hash': 'cafec240d998e4b6e92ad1329cd417e8e9cbd73157488889fd93a542de4a4844', 'datetime': '2019-02-25T20:47:01.483741+00:00', 'message': 'NTFS:\\Users\\SelmaBouvier\\Documents\\desktop.ini Type: file', 'source_long': 'File stat', 'source_short': 'FILE', 'tag': [], 'timestamp': 1551127621483741, 'timestamp_desc': 'Creation Time'}
#
# 2 --> {'data_type': 'fs:stat', 'parser': 'filestat', 'display_name': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini', 'file_entry_type': 'file', 'file_size': 282, 'file_system_type': 'NTFS', 'filename': '\\Users\\SelmaBouvier\\Desktop\\desktop.ini', 'inode': 1125899906949326, 'is_allocated': True, 'path_spec': '{"__type__": "PathSpec", "mft_entry": 106702, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Desktop\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}', 'sha256_hash': '4b9d687ac625690fd026ed4b236dad1cac90ef69e7ad256cc42766a065b50026', 'datetime': '2019-02-25T20:47:01.626798+00:00', 'message': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini Type: file', 'source_long': 'File stat', 'source_short': 'FILE', 'tag': [], 'timestamp': 1551127621626798, 'timestamp_desc': 'Content Modification Time'}
#
# 3 --> {'data_type': 'fs:stat', 'parser': 'filestat', 'display_name': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini', 'file_entry_type': 'file', 'file_size': 282, 'file_system_type': 'NTFS', 'filename': '\\Users\\SelmaBouvier\\Desktop\\desktop.ini', 'inode': 1125899906949326, 'is_allocated': True, 'path_spec': '{"__type__": "PathSpec", "mft_entry": 106702, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Desktop\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}', 'sha256_hash': '4b9d687ac625690fd026ed4b236dad1cac90ef69e7ad256cc42766a065b50026', 'datetime': '2019-02-25T20:47:01.626798+00:00', 'message': 'NTFS:\\Users\\SelmaBouvier\\Desktop\\desktop.ini Type: file', 'source_long': 'File stat', 'source_short': 'FILE', 'tag': [], 'timestamp': 1551127621626798, 'timestamp_desc': 'Metadata Modification Time'}
#
# 4 --> {'data_type': 'fs:stat', 'parser': 'filestat', 'display_name': 'NTFS:\\Users\\SelmaBouvier\\Downloads\\desktop.ini', 'file_entry_type': 'file', 'file_size': 282, 'file_system_type': 'NTFS', 'filename': '\\Users\\SelmaBouvier\\Downloads\\desktop.ini', 'inode': 844424930238731, 'is_allocated': True, 'path_spec': '{"__type__": "PathSpec", "mft_entry": 106763, "mft_attribute": 1, "location": "\\\\Users\\\\SelmaBouvier\\\\Downloads\\\\desktop.ini", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}', 'sha256_hash': 'b029393ea7b7cf644fb1c9f984f57c1980077562ee2e15d0ffd049c4c48098d3', 'datetime': '2019-02-25T20:47:01.651227+00:00', 'message': 'NTFS:\\Users\\SelmaBouvier\\Downloads\\desktop.ini Type: file', 'source_long': 'File stat', 'source_short': 'FILE', 'tag': [], 'timestamp': 1551127621651227, 'timestamp_desc': 'Creation Time'}

# %%
# We define a Python function to list results
#
def print_results(response):
  for num, doc in enumerate(response['hits']['hits']):
    print(num, '-->', doc['_source']) 

def print_results_detailed(response):
  for num, doc in enumerate(response['hits']['hits']):
    print('\n---------------------------------------------------------------------------------------------------\nresult numer: ',num) 
    for key, val in doc['_source'].items():
      print(key, val)

# %%
# we can try this function on the response we got earlier
#
print_results_detailed(response)
# Out:
# ---------------------------------------------------------------------------------------------------
# result numer:  0
# data_type windows:lnk:link
# parser lnk
# drive_serial_number 2935122090
# drive_type 3
# file_attribute_flags 0
# file_size 0
# link_target <My Computer> D:\OneDrive_1_3-18-2019.zip
# local_path D:\OneDrive_1_3-18-2019.zip
# volume_label SuperDuperSecretStuff
# path_spec {"__type__": "PathSpec", "mft_entry": 99166, "mft_attribute": 2, "location": "\\Users\\SelmaBouvier\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\OneDrive_1_3-18-2019.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash e0151b1d37b1ec68fa8192bc7e935d393e2af707900506114424d0be1ed55c6a
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\SelmaBouvier\AppData\Roaming\Microsoft\Windows\Recent\OneDrive_1_3-18-2019.lnk
# message File size: 0 File attribute flags: 0x00000000 Drive type: 3 Drive serial number: 0xaef268aa Volume label: SuperDuperSecretStuff Local path: D:\OneDrive_1_3-18-2019.zip Link target: <My Computer> D:\OneDrive_1_3-18-2019.zip
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  1
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# drive_serial_number 3438183451
# drive_type 3
# file_attribute_flags 0
# file_size 0
# link_target <My Computer> C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd
# local_path C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd
# volume_label
# path_spec {"__type__": "PathSpec", "mft_entry": 107233, "mft_attribute": 2, "location": "\\Users\\SelmaBouvier\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\5f7b5f1e01b83767.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 3ac2b8b746a145781ec853d20dfa8fb44b3e25b7c9c60d6b5e535cb2fd617385
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\SelmaBouvier\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\5f7b5f1e01b83767.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Drive type: 3 Drive serial number: 0xccee841b Volume label:  Local path: C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd Link target: <My Computer> C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  2
# data_type windows:lnk:link
# parser lnk
# drive_serial_number 3438183451
# drive_type 3
# file_attribute_flags 0
# file_size 0
# link_target <My Computer> {b4bfcc3a-db2c-424c-b029-7fe99a87c641}\EvenMoreSecretStuff.vhd
# local_path C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd
# relative_path ..\..\..\..\..\Desktop\EvenMoreSecretStuff.vhd
# volume_label
# working_directory C:\Users\SelmaBouvier\Desktop
# path_spec {"__type__": "PathSpec", "mft_entry": 97897, "mft_attribute": 2, "location": "\\Users\\SelmaBouvier\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\EvenMoreSecretStuff.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 2b7e2870d0fdfd9cd5290ed9e7d5f4e6b0a05f6865a5f5c11648b7cc9bdf1b94
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\SelmaBouvier\AppData\Roaming\Microsoft\Windows\Recent\EvenMoreSecretStuff.lnk
# message File size: 0 File attribute flags: 0x00000000 Drive type: 3 Drive serial number: 0xccee841b Volume label:  Local path: C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd Relative path: ..\..\..\..\..\Desktop\EvenMoreSecretStuff.vhd Working dir: C:\Users\SelmaBouvier\Desktop Link target: <My Computer> {b4bfcc3a-db2c-424c-b029-7fe99a87c641}\EvenMoreSecretStuff.vhd
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  3
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Applications> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 109497, "mft_attribute": 2, "location": "\\Users\\SelmaBouvier\\Desktop\\Microsoft Edge.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 07927a04901c74dfe28cdde56572b462fdc60e4e67d520a5167c96d5f4a6d880
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\SelmaBouvier\Desktop\Microsoft Edge.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Applications> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  4
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 94873, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\7e4dca80246863e3.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 1b40a264e98c6d12c61893d1bb8adb845280e719e5e49a1c50736752bba4e935
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\7e4dca80246863e3.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  5
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# path_spec {"__type__": "PathSpec", "mft_entry": 94873, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\7e4dca80246863e3.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 1b40a264e98c6d12c61893d1bb8adb845280e719e5e49a1c50736752bba4e935
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\7e4dca80246863e3.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  6
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# path_spec {"__type__": "PathSpec", "mft_entry": 99742, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\Network and Sharing Center.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash aec692cb17440be06ea59aaa9533faf0ad757ba01051045daff151965a1939ab
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\Network and Sharing Center.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  7
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# path_spec {"__type__": "PathSpec", "mft_entry": 62960, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\Programs and Features.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 089e3e03ddc975e6b2f0c4e0a8a5cbc056c9d8b21251ed7a79e74b5ce1d35bc3
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\Programs and Features.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  8
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# path_spec {"__type__": "PathSpec", "mft_entry": 492, "mft_attribute": 1, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\System.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 3b8c614a45d8033b5f612691ef780fca4fd1878fae0f8d4df2d0726e27b8e1df
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\System.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  9
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 99754, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\Network and Internet.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 0dbb3e08c13672c6bdc7ba9309392fab05dbd4dd7a31d043a8472a81d9013cc3
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\Network and Internet.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  10
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 62968, "mft_attribute": 1, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\Programs.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 43ab5fea35e7cd4c94faf26a2b75d9a90fdee2b6764b96a9642c86463eb98056
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\Programs.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  11
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 493, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\System and Security.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash dbc3c145520f48524ec7b67c0d2ef434df4811598f4dc40f6b1b19b7edd8eb81
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\System and Security.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  12
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# file_attribute_flags 0
# file_size 0
# link_target <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# path_spec {"__type__": "PathSpec", "mft_entry": 93543, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\9d1f905ce5044aee.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 38972e0fa14c90b37c967acf5b74f7273d4da3cd9833d4ce8adda6b4abac00db
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\9d1f905ce5044aee.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Link target: <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  13
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# file_attribute_flags 0
# file_size 0
# link_target <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# path_spec {"__type__": "PathSpec", "mft_entry": 62430, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\f18460fded109990.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash fe6dad6e28eb4866769dbee5c1b2f9d8ffa227ca670a21bfb028e5614f3c1946
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\f18460fded109990.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Link target: <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  14
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# path_spec {"__type__": "PathSpec", "mft_entry": 396, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\ms-settingsnetwork.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 5c5fce072e117d83ad4e93fa105d9f00f86d9e67065664b72a6a75c01b1373ab
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\ms-settingsnetwork.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time

# %%
# Opensearch query syntax is quite elaborate. We will provide some examples in this colab
# notice that results can have different fields. It depends on the data_type
# For a complete overview see the Opensearch reference documents
#
# https://opensearch.org/docs/latest/opensearch/query-dsl/index/
#
#query = '{"query": { "query_string": {"query": "source_short: WEBHIST"  }}}'
query = '{"query": { "query_string": {"query": "data_type: windows*link"  }}}'
#query = '{"query": { "query_string": {"query": "drive_type: 3"  }}}'
#query = '{"query": { "query_string": {"query": "drive_type: 3 AND data_type: windows*link" }}}'
#query = '{"query": { "range": {"drive_type": { "gte":0 , "lte":2 } }}}'
#query = '{"query": { "range": {"drive_type": { "gte":1 , "lte":3 } }}}'
#query = '{"query": { "query_string": {"query": "drive_type:>=0 and drive_type:<2"  }}}'
#query = '{"query": { "query_string": {"query": "file_size:>100000 "  }}}'
#query = '{"query": { "query_string": {"query": "file_size:<29696"  }}}'
#query = '{"query": { "range": {"file_size": { "gte":10000, "lte":100000 }  }}}'
#query = '{"query": { "query_string": {"query": "data_type: msie\\\\:*"  }}}'


response = client.search(index="newmus2019ctf", body=query, size=15)

print_results_detailed(response)
# Out:
# ---------------------------------------------------------------------------------------------------
# result numer:  0
# data_type windows:lnk:link
# parser lnk
# drive_serial_number 2935122090
# drive_type 3
# file_attribute_flags 0
# file_size 0
# link_target <My Computer> D:\OneDrive_1_3-18-2019.zip
# local_path D:\OneDrive_1_3-18-2019.zip
# volume_label SuperDuperSecretStuff
# path_spec {"__type__": "PathSpec", "mft_entry": 99166, "mft_attribute": 2, "location": "\\Users\\SelmaBouvier\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\OneDrive_1_3-18-2019.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash e0151b1d37b1ec68fa8192bc7e935d393e2af707900506114424d0be1ed55c6a
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\SelmaBouvier\AppData\Roaming\Microsoft\Windows\Recent\OneDrive_1_3-18-2019.lnk
# message File size: 0 File attribute flags: 0x00000000 Drive type: 3 Drive serial number: 0xaef268aa Volume label: SuperDuperSecretStuff Local path: D:\OneDrive_1_3-18-2019.zip Link target: <My Computer> D:\OneDrive_1_3-18-2019.zip
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  1
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# drive_serial_number 3438183451
# drive_type 3
# file_attribute_flags 0
# file_size 0
# link_target <My Computer> C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd
# local_path C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd
# volume_label
# path_spec {"__type__": "PathSpec", "mft_entry": 107233, "mft_attribute": 2, "location": "\\Users\\SelmaBouvier\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\5f7b5f1e01b83767.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 3ac2b8b746a145781ec853d20dfa8fb44b3e25b7c9c60d6b5e535cb2fd617385
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\SelmaBouvier\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\5f7b5f1e01b83767.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Drive type: 3 Drive serial number: 0xccee841b Volume label:  Local path: C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd Link target: <My Computer> C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  2
# data_type windows:lnk:link
# parser lnk
# drive_serial_number 3438183451
# drive_type 3
# file_attribute_flags 0
# file_size 0
# link_target <My Computer> {b4bfcc3a-db2c-424c-b029-7fe99a87c641}\EvenMoreSecretStuff.vhd
# local_path C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd
# relative_path ..\..\..\..\..\Desktop\EvenMoreSecretStuff.vhd
# volume_label
# working_directory C:\Users\SelmaBouvier\Desktop
# path_spec {"__type__": "PathSpec", "mft_entry": 97897, "mft_attribute": 2, "location": "\\Users\\SelmaBouvier\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\EvenMoreSecretStuff.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 2b7e2870d0fdfd9cd5290ed9e7d5f4e6b0a05f6865a5f5c11648b7cc9bdf1b94
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\SelmaBouvier\AppData\Roaming\Microsoft\Windows\Recent\EvenMoreSecretStuff.lnk
# message File size: 0 File attribute flags: 0x00000000 Drive type: 3 Drive serial number: 0xccee841b Volume label:  Local path: C:\Users\SelmaBouvier\Desktop\EvenMoreSecretStuff.vhd Relative path: ..\..\..\..\..\Desktop\EvenMoreSecretStuff.vhd Working dir: C:\Users\SelmaBouvier\Desktop Link target: <My Computer> {b4bfcc3a-db2c-424c-b029-7fe99a87c641}\EvenMoreSecretStuff.vhd
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  3
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Applications> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 109497, "mft_attribute": 2, "location": "\\Users\\SelmaBouvier\\Desktop\\Microsoft Edge.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 07927a04901c74dfe28cdde56572b462fdc60e4e67d520a5167c96d5f4a6d880
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\SelmaBouvier\Desktop\Microsoft Edge.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Applications> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  4
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 94873, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\7e4dca80246863e3.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 1b40a264e98c6d12c61893d1bb8adb845280e719e5e49a1c50736752bba4e935
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\7e4dca80246863e3.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  5
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# path_spec {"__type__": "PathSpec", "mft_entry": 94873, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\7e4dca80246863e3.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 1b40a264e98c6d12c61893d1bb8adb845280e719e5e49a1c50736752bba4e935
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\7e4dca80246863e3.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  6
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# path_spec {"__type__": "PathSpec", "mft_entry": 99742, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\Network and Sharing Center.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash aec692cb17440be06ea59aaa9533faf0ad757ba01051045daff151965a1939ab
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\Network and Sharing Center.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  7
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# path_spec {"__type__": "PathSpec", "mft_entry": 62960, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\Programs and Features.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 089e3e03ddc975e6b2f0c4e0a8a5cbc056c9d8b21251ed7a79e74b5ce1d35bc3
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\Programs and Features.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  8
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# path_spec {"__type__": "PathSpec", "mft_entry": 492, "mft_attribute": 1, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\System.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 3b8c614a45d8033b5f612691ef780fca4fd1878fae0f8d4df2d0726e27b8e1df
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\System.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00> <UNKNOWN: 0x71>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  9
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 99754, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\Network and Internet.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 0dbb3e08c13672c6bdc7ba9309392fab05dbd4dd7a31d043a8472a81d9013cc3
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\Network and Internet.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  10
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 62968, "mft_attribute": 1, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\Programs.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 43ab5fea35e7cd4c94faf26a2b75d9a90fdee2b6764b96a9642c86463eb98056
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\Programs.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  11
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Control Panel> <UNKNOWN: 0x00>
# path_spec {"__type__": "PathSpec", "mft_entry": 493, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\System and Security.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash dbc3c145520f48524ec7b67c0d2ef434df4811598f4dc40f6b1b19b7edd8eb81
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\System and Security.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Control Panel> <UNKNOWN: 0x00>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  12
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# file_attribute_flags 0
# file_size 0
# link_target <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# path_spec {"__type__": "PathSpec", "mft_entry": 93543, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\9d1f905ce5044aee.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 38972e0fa14c90b37c967acf5b74f7273d4da3cd9833d4ce8adda6b4abac00db
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\9d1f905ce5044aee.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Link target: <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  13
# data_type windows:lnk:link
# parser olecf/olecf_automatic_destinations/lnk
# file_attribute_flags 0
# file_size 0
# link_target <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# path_spec {"__type__": "PathSpec", "mft_entry": 62430, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\AutomaticDestinations\\f18460fded109990.automaticDestinations-ms", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash fe6dad6e28eb4866769dbee5c1b2f9d8ffa227ca670a21bfb028e5614f3c1946
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\AutomaticDestinations\f18460fded109990.automaticDestinations-ms
# message File size: 0 File attribute flags: 0x00000000 Link target: <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  14
# data_type windows:lnk:link
# parser lnk
# file_attribute_flags 0
# file_size 0
# link_target <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# path_spec {"__type__": "PathSpec", "mft_entry": 396, "mft_attribute": 2, "location": "\\Users\\Administrator\\AppData\\Roaming\\Microsoft\\Windows\\Recent\\ms-settingsnetwork.lnk", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 5c5fce072e117d83ad4e93fa105d9f00f86d9e67065664b72a6a75c01b1373ab
# datetime 1970-01-01T00:00:00.000000+00:00
# display_name NTFS:\Users\Administrator\AppData\Roaming\Microsoft\Windows\Recent\ms-settingsnetwork.lnk
# message File size: 0 File attribute flags: 0x00000000 Link target: <Internet Explorer (Homepage)> <UNKNOWN: 0x61>
# source_long Windows Shortcut
# source_short LNK
# tag []
# timestamp 0
# timestamp_desc Not a time

# %% [markdown]
# ## 6 Elasticsearch field aggregation

# %%
# First we define some helper functions:

def print_facets(agg_dict):
  sum=0
  for field, val in agg_dict:
      print("facets of field ", field,':')
      for bucket in val['buckets']:
        for key in bucket:
          if key=='key':
            print('\t',bucket[key],end='=')
          else:
            print(bucket[key],end='')
            sum = sum + bucket[key]
        print()
      print("total number of hits for ",field," is ",sum)

def print_hit_stats(response):
  print('hit stats:')
  for key, val in response['hits'].items():
      print(key, val)
  print('\n')

# %%
querystring = '{ "query_string": {"query": "source_short: WEBHIST"  }}'

query = '{"query": %s}' % querystring

print(query)
# Out:
# {"query": { "query_string": {"query": "source_short: WEBHIST"  }}}

# %%
# Aggregating results is one of the most powerful options in Elasticsearch
#
# https://opensearch.org/docs/latest/opensearch/aggregations/
#
querystring = '{ "query_string": {"query": "SelmaBouvier"  }}'
facets = '"aggs": { "data_type": { "terms": { "field": "data_type.keyword"}}}'
query = '{"query": %s,%s}' % (querystring,facets)

print(query)
# Out:
# {"query": { "query_string": {"query": "SelmaBouvier"  }},"aggs": { "data_type": { "terms": { "field": "data_type.keyword"}}}}

# %%
response = client.search(index="newmus2019ctf", body=query, size=0)
print_hit_stats(response)

print_facets(response['aggregations'].items())
# print_results(response)
# Out:
# hit stats:
# total {'value': 3820, 'relation': 'eq'}
# max_score None
# hits []
#
#
# facets of field  data_type :
# 	 windows:evtx:record=2698
# 	 msie:webcache:container=522
# 	 fs:stat=220
# 	 windows:prefetch:execution=172
# 	 windows:lnk:link=53
# 	 msie:webcache:containers=31
# 	 windows:registry:key_value=28
# 	 windows:registry:appcompatcache=27
# 	 windows:distributed_link_tracking:creation=25
# 	 windows:shell_item:file_entry=21
# total number of hits for  data_type  is  3797

# %%
# Aggregate accross multiple facets
#
querystring = '{ "query_string": {"query": "SelmaBouvier"  }}'

facets = '"aggs": { "parser": { "terms": { "field": "parser.keyword"}},  "data_type": { "terms": { "field": "data_type.keyword"}}}'
query = '{"query": %s,%s}' % (querystring,facets)

response = client.search(index="newmus2019ctf", body=query, size=0)

print_facets(response['aggregations'].items())
# Out:
# facets of field  parser :
# 	 winreg/winreg_default=181109
# 	 winevtx=58506
# 	 usnjrnl=1005
# 	 winreg/windows_services=241
# 	 pe=86
# 	 olecf/olecf_automatic_destinations/lnk=52
# 	 lnk=19
# 	 winreg/windows_task_cache=16
# 	 olecf/olecf_automatic_destinations=13
# 	 winreg/windows_sam_users=7
# total number of hits for  parser  is  241054
# facets of field  data_type :
# 	 windows:registry:key_value=181109
# 	 windows:evtx:record=58506
# 	 fs:ntfs:usn_change=1005
# 	 windows:registry:service=241
# 	 pe=86
# 	 windows:lnk:link=71
# 	 task_scheduler:task_cache:entry=16
# 	 olecf:dest_list:entry=13
# 	 windows:registry:sam_users=7
# total number of hits for  data_type  is  482108

# %%
# aggregate accross datetime
# 
# also see pipeline aggregations https://opensearch.org/docs/latest/opensearch/pipeline-agg/

querystring = '{ "query_string": {"query": "\\\<\\\/Event\\\>"  }}'

facets = '"aggs": { "datetime": { "date_histogram": { "field": "datetime", "calendar_interval": "year"}}}'

query = '{"query": %s,%s}' % (querystring,facets)

response = client.search(index="newmus2019ctf", body=query, size=0)

response
# Out:
# {'took': 106,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'datetime': {'buckets': [{'key_as_string': '1970-01-01T00:00:00.000Z',
#      'key': 0,
#      'doc_count': 2},
#     {'key_as_string': '1971-01-01T00:00:00.000Z',
#      'key': 31536000000,
#      'doc_count': 0},
#     {'key_as_string': '1972-01-01T00:00:00.000Z',
#      'key': 63072000000,
#      'doc_count': 0},
#     {'key_as_string': '1973-01-01T00:00:00.000Z',
#      'key': 94694400000,
#      'doc_count': 0},
#     {'key_as_string': '1974-01-01T00:00:00.000Z',
#      'key': 126230400000,
#      'doc_count': 0},
#     {'key_as_string': '1975-01-01T00:00:00.000Z',
#      'key': 157766400000,
#      'doc_count': 0},
#     {'key_as_string': '1976-01-01T00:00:00.000Z',
#      'key': 189302400000,
#      'doc_count': 0},
#     {'key_as_string': '1977-01-01T00:00:00.000Z',
#      'key': 220924800000,
#      'doc_count': 0},
#     {'key_as_string': '1978-01-01T00:00:00.000Z',
#      'key': 252460800000,
#      'doc_count': 0},
#     {'key_as_string': '1979-01-01T00:00:00.000Z',
#      'key': 283996800000,
#      'doc_count': 0},
#     {'key_as_string': '1980-01-01T00:00:00.000Z',
#      'key': 315532800000,
#      'doc_count': 0},
#     {'key_as_string': '1981-01-01T00:00:00.000Z',
#      'key': 347155200000,
#      'doc_count': 0},
#     {'key_as_string': '1982-01-01T00:00:00.000Z',
#      'key': 378691200000,
#      'doc_count': 0},
#     {'key_as_string': '1983-01-01T00:00:00.000Z',
#      'key': 410227200000,
#      'doc_count': 0},
#     {'key_as_string': '1984-01-01T00:00:00.000Z',
#      'key': 441763200000,
#      'doc_count': 0},
#     {'key_as_string': '1985-01-01T00:00:00.000Z',
#      'key': 473385600000,
#      'doc_count': 0},
#     {'key_as_string': '1986-01-01T00:00:00.000Z',
#      'key': 504921600000,
#      'doc_count': 0},
#     {'key_as_string': '1987-01-01T00:00:00.000Z',
#      'key': 536457600000,
#      'doc_count': 0},
#     {'key_as_string': '1988-01-01T00:00:00.000Z',
#      'key': 567993600000,
#      'doc_count': 0},
#     {'key_as_string': '1989-01-01T00:00:00.000Z',
#      'key': 599616000000,
#      'doc_count': 0},
#     {'key_as_string': '1990-01-01T00:00:00.000Z',
#      'key': 631152000000,
#      'doc_count': 0},
#     {'key_as_string': '1991-01-01T00:00:00.000Z',
#      'key': 662688000000,
#      'doc_count': 0},
#     {'key_as_string': '1992-01-01T00:00:00.000Z',
#      'key': 694224000000,
#      'doc_count': 0},
#     {'key_as_string': '1993-01-01T00:00:00.000Z',
#      'key': 725846400000,
#      'doc_count': 0},
#     {'key_as_string': '1994-01-01T00:00:00.000Z',
#      'key': 757382400000,
#      'doc_count': 0},
#     {'key_as_string': '1995-01-01T00:00:00.000Z',
#      'key': 788918400000,
#      'doc_count': 0},
#     {'key_as_string': '1996-01-01T00:00:00.000Z',
#      'key': 820454400000,
#      'doc_count': 0},
#     {'key_as_string': '1997-01-01T00:00:00.000Z',
#      'key': 852076800000,
#      'doc_count': 0},
#     {'key_as_string': '1998-01-01T00:00:00.000Z',
#      'key': 883612800000,
#      'doc_count': 0},
#     {'key_as_string': '1999-01-01T00:00:00.000Z',
#      'key': 915148800000,
#      'doc_count': 0},
#     {'key_as_string': '2000-01-01T00:00:00.000Z',
#      'key': 946684800000,
#      'doc_count': 0},
#     {'key_as_string': '2001-01-01T00:00:00.000Z',
#      'key': 978307200000,
#      'doc_count': 0},
#     {'key_as_string': '2002-01-01T00:00:00.000Z',
#      'key': 1009843200000,
#      'doc_count': 0},
#     {'key_as_string': '2003-01-01T00:00:00.000Z',
#      'key': 1041379200000,
#      'doc_count': 0},
#     {'key_as_string': '2004-01-01T00:00:00.000Z',
#      'key': 1072915200000,
#      'doc_count': 2},
#     {'key_as_string': '2005-01-01T00:00:00.000Z',
#      'key': 1104537600000,
#      'doc_count': 2},
#     {'key_as_string': '2006-01-01T00:00:00.000Z',
#      'key': 1136073600000,
#      'doc_count': 0},
#     {'key_as_string': '2007-01-01T00:00:00.000Z',
#      'key': 1167609600000,
#      'doc_count': 0},
#     {'key_as_string': '2008-01-01T00:00:00.000Z',
#      'key': 1199145600000,
#      'doc_count': 0},
#     {'key_as_string': '2009-01-01T00:00:00.000Z',
#      'key': 1230768000000,
#      'doc_count': 1},
#     {'key_as_string': '2010-01-01T00:00:00.000Z',
#      'key': 1262304000000,
#      'doc_count': 6},
#     {'key_as_string': '2011-01-01T00:00:00.000Z',
#      'key': 1293840000000,
#      'doc_count': 4},
#     {'key_as_string': '2012-01-01T00:00:00.000Z',
#      'key': 1325376000000,
#      'doc_count': 69},
#     {'key_as_string': '2013-01-01T00:00:00.000Z',
#      'key': 1356998400000,
#      'doc_count': 0},
#     {'key_as_string': '2014-01-01T00:00:00.000Z',
#      'key': 1388534400000,
#      'doc_count': 0},
#     {'key_as_string': '2015-01-01T00:00:00.000Z',
#      'key': 1420070400000,
#      'doc_count': 0},
#     {'key_as_string': '2016-01-01T00:00:00.000Z',
#      'key': 1451606400000,
#      'doc_count': 2},
#     {'key_as_string': '2017-01-01T00:00:00.000Z',
#      'key': 1483228800000,
#      'doc_count': 0},
#     {'key_as_string': '2018-01-01T00:00:00.000Z',
#      'key': 1514764800000,
#      'doc_count': 180714},
#     {'key_as_string': '2019-01-01T00:00:00.000Z',
#      'key': 1546300800000,
#      'doc_count': 60252}]}}}

# %%
# aggregate accross file_size (must have changed type text to long in mappings file before psort.py)
# 
# also see pipeline aggregations https://opensearch.org/docs/latest/opensearch/pipeline-agg/

querystring = '{ "query_string": {"query": "file_size:<100000000"  }}'

facets = '"aggs": { "file_size": { "histogram": { "field": "file_size", "interval": 10000000}}}'

query = '{"query": %s,%s}' % (querystring,facets)

response = client.search(index="newmus2019ctf", body=query, size=0)

print_facets(response['aggregations'].items())
# Out:
# facets of field  file_size :
# 	 0.0=3827
# 	 10000000.0=20
# 	 20000000.0=28
# 	 30000000.0=4
# 	 40000000.0=11
# 	 50000000.0=0
# 	 60000000.0=0
# 	 70000000.0=4
# total number of hits for  file_size  is  3894

# %%
# date range search

query = '{"query": { "query_string": {"query": "datetime:[2019-03-12 TO 2019-03-22]"  }}}'

print(query)
response = client.search(index="newmus2019ctf", body=query, size=10)
print_results_detailed(response)
# Out:
# {"query": { "query_string": {"query": "datetime:[2019-03-12 TO 2019-03-22]"  }}}
#
# ---------------------------------------------------------------------------------------------------
# result numer:  0
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 100
# event_level 4
# message_identifier 100
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4679
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{5AE2C742-1D4A-4568-A41A-73B87D7A808B}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>100</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>12</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:00:06.714495300Z"/>
#     <EventRecordID>4679</EventRecordID>
#     <Correlation ActivityID="{5AE2C742-1D4A-4568-A41A-73B87D7A808B}"/>
#     <Execution ProcessID="2592" ThreadID="7176"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{5AE2C742-1D4A-4568-A41A-73B87D7A808B}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:00:06.714495+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [100 / 0x0064] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{5AE2C742-1D4A-4568-A41A-73B87D7A808B}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4679 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552348806714495
# timestamp_desc Content Modification Time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  1
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 100
# event_level 4
# message_identifier 100
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4679
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{5AE2C742-1D4A-4568-A41A-73B87D7A808B}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>100</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>12</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:00:06.714495300Z"/>
#     <EventRecordID>4679</EventRecordID>
#     <Correlation ActivityID="{5AE2C742-1D4A-4568-A41A-73B87D7A808B}"/>
#     <Execution ProcessID="2592" ThreadID="7176"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{5AE2C742-1D4A-4568-A41A-73B87D7A808B}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:00:06.714495+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [100 / 0x0064] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{5AE2C742-1D4A-4568-A41A-73B87D7A808B}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4679 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552348806714495
# timestamp_desc Creation Time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  2
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 105
# event_level 4
# message_identifier 105
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4680
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{5AE2C742-1D4A-4568-A41A-73B87D7A808B}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>105</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>13</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:00:06.714526100Z"/>
#     <EventRecordID>4680</EventRecordID>
#     <Correlation ActivityID="{5AE2C742-1D4A-4568-A41A-73B87D7A808B}"/>
#     <Execution ProcessID="2592" ThreadID="7176"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{5AE2C742-1D4A-4568-A41A-73B87D7A808B}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:00:06.714526+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [105 / 0x0069] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{5AE2C742-1D4A-4568-A41A-73B87D7A808B}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4680 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552348806714526
# timestamp_desc Content Modification Time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  3
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 105
# event_level 4
# message_identifier 105
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4680
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{5AE2C742-1D4A-4568-A41A-73B87D7A808B}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>105</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>13</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:00:06.714526100Z"/>
#     <EventRecordID>4680</EventRecordID>
#     <Correlation ActivityID="{5AE2C742-1D4A-4568-A41A-73B87D7A808B}"/>
#     <Execution ProcessID="2592" ThreadID="7176"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{5AE2C742-1D4A-4568-A41A-73B87D7A808B}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:00:06.714526+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [105 / 0x0069] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{5AE2C742-1D4A-4568-A41A-73B87D7A808B}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4680 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552348806714526
# timestamp_desc Creation Time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  4
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 100
# event_level 4
# message_identifier 100
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4681
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{45492767-8ED6-4A3E-9B20-11C4B96A38EC}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>100</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>12</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:05:06.718384300Z"/>
#     <EventRecordID>4681</EventRecordID>
#     <Correlation ActivityID="{45492767-8ED6-4A3E-9B20-11C4B96A38EC}"/>
#     <Execution ProcessID="2592" ThreadID="12032"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{45492767-8ED6-4A3E-9B20-11C4B96A38EC}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:05:06.718384+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [100 / 0x0064] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{45492767-8ED6-4A3E-9B20-11C4B96A38EC}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4681 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552349106718384
# timestamp_desc Content Modification Time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  5
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 100
# event_level 4
# message_identifier 100
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4681
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{45492767-8ED6-4A3E-9B20-11C4B96A38EC}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>100</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>12</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:05:06.718384300Z"/>
#     <EventRecordID>4681</EventRecordID>
#     <Correlation ActivityID="{45492767-8ED6-4A3E-9B20-11C4B96A38EC}"/>
#     <Execution ProcessID="2592" ThreadID="12032"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{45492767-8ED6-4A3E-9B20-11C4B96A38EC}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:05:06.718384+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [100 / 0x0064] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{45492767-8ED6-4A3E-9B20-11C4B96A38EC}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4681 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552349106718384
# timestamp_desc Creation Time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  6
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 105
# event_level 4
# message_identifier 105
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4682
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{45492767-8ED6-4A3E-9B20-11C4B96A38EC}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>105</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>13</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:05:06.718410300Z"/>
#     <EventRecordID>4682</EventRecordID>
#     <Correlation ActivityID="{45492767-8ED6-4A3E-9B20-11C4B96A38EC}"/>
#     <Execution ProcessID="2592" ThreadID="12032"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{45492767-8ED6-4A3E-9B20-11C4B96A38EC}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:05:06.718410+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [105 / 0x0069] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{45492767-8ED6-4A3E-9B20-11C4B96A38EC}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4682 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552349106718410
# timestamp_desc Content Modification Time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  7
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 105
# event_level 4
# message_identifier 105
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4682
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{45492767-8ED6-4A3E-9B20-11C4B96A38EC}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>105</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>13</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:05:06.718410300Z"/>
#     <EventRecordID>4682</EventRecordID>
#     <Correlation ActivityID="{45492767-8ED6-4A3E-9B20-11C4B96A38EC}"/>
#     <Execution ProcessID="2592" ThreadID="12032"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{45492767-8ED6-4A3E-9B20-11C4B96A38EC}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:05:06.718410+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [105 / 0x0069] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{45492767-8ED6-4A3E-9B20-11C4B96A38EC}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4682 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552349106718410
# timestamp_desc Creation Time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  8
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 100
# event_level 4
# message_identifier 100
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4683
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{52F8D487-5472-4809-AF48-E9A593EBAD80}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>100</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>12</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:10:06.728932900Z"/>
#     <EventRecordID>4683</EventRecordID>
#     <Correlation ActivityID="{52F8D487-5472-4809-AF48-E9A593EBAD80}"/>
#     <Execution ProcessID="2592" ThreadID="2392"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{52F8D487-5472-4809-AF48-E9A593EBAD80}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:10:06.728933+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [100 / 0x0064] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{52F8D487-5472-4809-AF48-E9A593EBAD80}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4683 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552349406728933
# timestamp_desc Content Modification Time
#
# ---------------------------------------------------------------------------------------------------
# result numer:  9
# data_type windows:evtx:record
# parser winevtx
# computer_name DESKTOP-0QT8017
# event_identifier 100
# event_level 4
# message_identifier 100
# offset 0
# provider_identifier {6bba3851-2c7e-4dea-8f54-31e5afd029e3}
# record_number 4683
# recovered False
# source_name Microsoft-Windows-Diagnosis-DPS
# strings ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{52F8D487-5472-4809-AF48-E9A593EBAD80}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}']
# user_sid S-1-5-19
# xml_string <Event xmlns="http://schemas.microsoft.com/win/2004/08/events/event">
#   <System>
#     <Provider Name="Microsoft-Windows-Diagnosis-DPS" Guid="{6BBA3851-2C7E-4DEA-8F54-31E5AFD029E3}"/>
#     <EventID>100</EventID>
#     <Version>0</Version>
#     <Level>4</Level>
#     <Task>1</Task>
#     <Opcode>12</Opcode>
#     <Keywords>0x4000000800000000</Keywords>
#     <TimeCreated SystemTime="2019-03-12T00:10:06.728932900Z"/>
#     <EventRecordID>4683</EventRecordID>
#     <Correlation ActivityID="{52F8D487-5472-4809-AF48-E9A593EBAD80}"/>
#     <Execution ProcessID="2592" ThreadID="2392"/>
#     <Channel>Microsoft-Windows-Diagnosis-DPS/Operational</Channel>
#     <Computer>DESKTOP-0QT8017</Computer>
#     <Security UserID="S-1-5-19"/>
#   </System>
#   <EventData>
#     <Data Name="ScenarioId">{180B3A99-8C39-4F12-B631-2031998EFE45}</Data>
#     <Data Name="InstanceId">{52F8D487-5472-4809-AF48-E9A593EBAD80}</Data>
#     <Data Name="OriginalActivityId">{00000000-0000-0000-0000-000000000000}</Data>
#     <Data Name="DiagnosticModuleImageName">%windir%\system32\radardt.dll</Data>
#     <Data Name="DiagnosticModuleId">{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}</Data>
#   </EventData>
# </Event>
#
# path_spec {"__type__": "PathSpec", "mft_entry": 83752, "mft_attribute": 2, "location": "\\Windows\\System32\\winevt\\Logs\\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}
# sha256_hash 94786297c4496cad71447aa04498e17748a7efea3906c3e708c64dbff9d4c74b
# datetime 2019-03-12T00:10:06.728933+00:00
# display_name NTFS:\Windows\System32\winevt\Logs\Microsoft-Windows-Diagnosis-DPS%4Operational.evtx
# message [100 / 0x0064] Provider identifier: {6bba3851-2c7e-4dea-8f54-31e5afd029e3} Source Name: Microsoft-Windows-Diagnosis-DPS Strings: ['{180B3A99-8C39-4F12-B631-2031998EFE45}', '{52F8D487-5472-4809-AF48-E9A593EBAD80}', '{00000000-0000-0000-0000-000000000000}', '%windir%\\system32\\radardt.dll', '{45DE1EA9-10BC-4F96-9B21-4B6B83DBF476}'] Computer Name: DESKTOP-0QT8017 Record Number: 4683 Event Level: 4
# source_long WinEVTX
# source_short EVT
# tag []
# timestamp 1552349406728933
# timestamp_desc Creation Time

# %% [markdown]
# ## 7 Putting Elasticsearch json out into a Pandas dataframe

# %%
# the out is json format which we can store in a pandas dataframe
import pandas as pd
import json
from io import StringIO

output = !curl -sX GET "https://localhost:9200/_search?q=logon" -u admin:admin --insecure
df = pd.read_json(StringIO(output[0]))

# %%
df.head
# Out:
# <bound method NDFrame.head of             took  timed_out  _shards  \
# total        133      False      3.0
# successful   133      False      3.0
# skipped      133      False      0.0
# failed       133      False      0.0
# max_score    133      False      NaN
# hits         133      False      NaN
#
#                                                          hits
# total                        {'value': 431, 'relation': 'eq'}
# successful                                                NaN
# skipped                                                   NaN
# failed                                                    NaN
# max_score                                           10.792242
# hits        [{'_index': 'newmus2019ctf', '_id': 'BEsnpoIBN...  >

# %%
df['hits']['hits'][:1]
# Out:
# [{'_index': 'newmus2019ctf',
#   '_id': 'BEsnpoIBNwEKF-Xi-gHh',
#   '_score': 10.792242,
#   '_source': {'data_type': 'fs:stat',
#    'parser': 'filestat',
#    'display_name': 'NTFS:\\Windows\\System32\\Tasks\\Microsoft\\Windows\\Offline Files\\Logon Synchronization',
#    'file_entry_type': 'file',
#    'file_size': 2840,
#    'file_system_type': 'NTFS',
#    'filename': '\\Windows\\System32\\Tasks\\Microsoft\\Windows\\Offline Files\\Logon Synchronization',
#    'inode': 281474976794476,
#    'is_allocated': True,
#    'path_spec': '{"__type__": "PathSpec", "mft_entry": 83820, "mft_attribute": 2, "location": "\\\\Windows\\\\System32\\\\Tasks\\\\Microsoft\\\\Windows\\\\Offline Files\\\\Logon Synchronization", "parent": {"__type__": "PathSpec", "part_index": 2, "start_offset": 576716800, "location": "/p1", "parent": {"__type__": "PathSpec", "parent": {"__type__": "PathSpec", "location": "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01", "type_indicator": "OS"}, "type_indicator": "EWF"}, "type_indicator": "TSK_PARTITION"}, "type_indicator": "NTFS"}',
#    'sha256_hash': '2b5a9cf7349f7072bd941b279d072aba5cfe7f819636f310875d24c5fab0c551',
#    'datetime': '2018-07-28T07:25:05.511475+00:00',
#    'message': 'NTFS:\\Windows\\System32\\Tasks\\Microsoft\\Windows\\Offline Files\\Logon Synchronization Type: file',
#    'source_long': 'File stat',
#    'source_short': 'FILE',
#    'tag': [],
#    'timestamp': 1532762705511475,
#    'timestamp_desc': 'Content Modification Time'}}]

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1 Use elasticsearch to filter events in between 2019-03-12 and 2019-03-22

# %%
# Your answer

# %% [markdown]
# ## 2 Write a query that performs an aggregation on source_long and source_short (can you find the right field names?)

# %%
# Your answer

# %% [markdown]
# ## 3 Combine your date range filter from exercise 1 with facet aggregation in exercise 2

# %%
# Your answer

# %% [markdown]
# ## 4 ***Advanced*** Use opensearch facet aggregation to create a treemap visualisation of a filtered set of events in the index.

# %% [markdown]
# ####Step 1
# The source_short and source_long look interesting for visualisation let's focus on REG, LOG and FILE and run a query. Try the following to see what this looks like:

# %%
facets = '"aggs": {   "source_long": { "terms": { "field": "source_long.keyword"}}, "source_short": { "terms": { "field": "source_short.keyword"}}}'
daterange = 'datetime:[2019-03-12 TO 2019-03-22]'
# FILE:
querystring = '{ "query_string": {"query": "%s AND  source_short:(FILE OR LOG OR REG)"  }}' % daterange
query = '{"query": %s,%s}' % (querystring,facets)
response = client.search(index="newmus2019ctf", body=query, size=0,track_total_hits=True)
print_facets(response['aggregations'].items())

# %% [markdown]
# Why is this not very helpful for a treemap visualisation?

# %%
# Your answer

# %% [markdown]
# ####Step 2
# One approach is to aggregate only accross source_long an run 3 separate queries for source_short equal to REG, LOG and FILE respectively and then combine the results into a single dataframe that we can visualise:

# %%
# Your answer. If you are struggling you can skip this step and move on to step 3.

# %% [markdown]
# ####Step 3
# Opensearch can also aggregate accros multiple fields combined. This is called multi_terms aggregation which aggregates accross all (source_long, source_short) value pairs. Note: by default opensearch returns 10 buckets max. We set it to 20 here using the size parameter.
#
# See https://opensearch.org/docs/2.0/opensearch/bucket-agg/ for more information about opensearch and multi_term aggregation.

# %%
# Your answer

# %% [markdown]
# ####Step 4
# The exercise asked for aggregation accross 3 fields. So let's add the parser field and deepen our treemap visualisation

# %%
# Your answer
