# %% [markdown]
# <a href="https://colab.research.google.com/github/HansHenseler/masdav2022/blob/main/Part_4_Exercise_Answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Opensearch and log2timeline
#
# Exercise 4:
#
# Master of Advanced Studies in Digital Forensics & Cyber Investigation
#
# Data Analytics and Visualization for Digital Forensics
#
# (c) Hans Henseler, 2022

# %% [markdown]
# ## 1 The examples are in the Part 4 notebook. This notebook only contains initializations needed to run the exercises at the end
#
# First install Plaso-tools as we did in exercise 3

# %%
# various install steps to install plaso tools and dependencies to get plaso working in colab
# -y option is to skip user interaction
# some packages need to be deinstalled and reinstalled to resolve dependencies
# these steps take app. 3 minutes to complete on a fresh colab instance
# !add-apt-repository -y ppa:gift/stable
# !apt update
# !apt-get update
# !apt install plaso-tools
# !pip uninstall -y pytsk3
# !pip install pytsk3
# !pip uninstall -y yara-python
# !pip install yara-python
# !pip uninstall -y lz4
# !pip install lz4

# %%
# This notebook was tested with version 20220724 (psort.py assumes opensearch and longer elasticsearch)

# !psort.py -V
# Out:
# plaso - psort version 20220724

# %%
# check if plaso tools were installed by running psort.py

# !psort.py -o list
# Out:
# ******************************** Output Modules ********************************
#          Name : Description
# --------------------------------------------------------------------------------
#       dynamic : Dynamic selection of fields for a separated value output
#                 format.
#          json : Saves the events into a JSON format.
#     json_line : Saves the events into a JSON line format.
#           kml : Saves events with geography data into a KML format.
#        l2tcsv : CSV format used by legacy log2timeline, with 17 fixed fields.
#        l2ttln : Extended TLN 7 field | delimited output.
#          null : Output module that does not output anything.
#    opensearch : Saves the events into an OpenSearch database.
# opensearch_ts : Saves the events into an OpenSearch database for use with
#                 Timesketch.
#         rawpy : native (or "raw") Python output.
#           tln : TLN 5 field | delimited output.
#          xlsx : Excel Spreadsheet (XLSX) output
# --------------------------------------------------------------------------------

# %%
# !wget -q https://artifacts.opensearch.org/releases/bundle/opensearch/2.2.0/opensearch-2.2.0-linux-x64.tar.gz
# !wget -q https://artifacts.opensearch.org/releases/bundle/opensearch/2.2.0/opensearch-2.2.0-linux-x64.tar.gz.sha512
# !tar -zxf opensearch-2.2.0-linux-x64.tar.gz
# !shasum -a 512 -c opensearch-2.2.0-linux-x64.tar.gz.sha512
# Out:
# opensearch-2.2.0-linux-x64.tar.gz: OK

# %%
# change the owner of the Opensearch filetree from root to daemon because Opensearch cannot run as root.

# !sudo chown -R daemon:daemon opensearch-2.2.0/

# %% [markdown]
# Run Elasticsearch as a daemon process

# %%
import time

# %%
# start Opensearch from the commandline as user daemon. 

# !sudo -H -u daemon sh -c  "opensearch-2.2.0/opensearch-tar-install.sh 1> /content/opensearch-2.2.0/logs/os.log 2> /content/opensearch-2.2.0/logs/os.err &"

# %%
# Sleep for few seconds to let the instance start.
time.sleep(20)

# %% [markdown]
# Once the instance has been started, grep for opensearch in the processes list to confirm the availability.

# %%
# !ps -ef | grep opensearch
# Out:
# daemon      8014       1 99 18:55 ?        00:00:38 /content/opensearch-2.2.0/jdk/bin/java -Xshare:auto -Dopensearch.networkaddress.cache.ttl=60 -Dopensearch.networkaddress.cache.negative.ttl=10 -XX:+AlwaysPreTouch -Xss1m -Djava.awt.headless=true -Dfile.encoding=UTF-8 -Djna.nosys=true -XX:-OmitStackTraceInFastThrow -XX:+ShowCodeDetailsInExceptionMessages -Dio.netty.noUnsafe=true -Dio.netty.noKeySetOptimization=true -Dio.netty.recycler.maxCapacityPerThread=0 -Dio.netty.allocator.numDirectArenas=0 -Dlog4j.shutdownHookEnabled=false -Dlog4j2.disable.jmx=true -Djava.locale.providers=SPI,COMPAT -Xms1g -Xmx1g -XX:+UseG1GC -XX:G1ReservePercent=25 -XX:InitiatingHeapOccupancyPercent=30 -Djava.io.tmpdir=/tmp/opensearch-7220716448761113169 -XX:+HeapDumpOnOutOfMemoryError -XX:HeapDumpPath=data -XX:ErrorFile=logs/hs_err_pid%p.log -Xlog:gc*,gc+age=trace,safepoint:file=logs/gc.log:utctime,pid,tags:filecount=32,filesize=64m -Dclk.tck=100 -Djdk.attach.allowAttachSelf=true -Djava.security.policy=/content/opensearch-2.2.0/config/opensearch-performance-analyzer/opensearch_security.policy --add-opens=jdk.attach/sun.tools.attach=ALL-UNNAMED -XX:MaxDirectMemorySize=536870912 -Dopensearch.path.home=/content/opensearch-2.2.0 -Dopensearch.path.conf=/content/opensearch-2.2.0/config -Dopensearch.distribution.type=tar -Dopensearch.bundled_jdk=true -cp /content/opensearch-2.2.0/lib/* org.opensearch.bootstrap.OpenSearch
# root        8374      55  0 18:56 ?        00:00:00 /bin/bash -c ps -ef | grep opensearch
# root        8376    8374  0 18:56 ?        00:00:00 grep opensearch

# %% [markdown]
# query the base endpoint to retrieve information about the cluster.

# %%
# !curl -XGET https://localhost:9200 -u 'admin:admin' --insecure
# Out:
# {
#   "name" : "74aabc422dc4",
#   "cluster_name" : "opensearch",
#   "cluster_uuid" : "HRYLb7jXTrqm2LBPZpXDNg",
#   "version" : {
#     "distribution" : "opensearch",
#     "number" : "2.2.0",
#     "build_type" : "tar",
#     "build_hash" : "b1017fa3b9a1c781d4f34ecee411e0cdf930a515",
#     "build_date" : "2022-08-09T02:27:25.256769336Z",
#     "build_snapshot" : false,
#     "lucene_version" : "9.3.0",
#     "minimum_wire_compatibility_version" : "7.10.0",
#     "minimum_index_compatibility_version" : "7.0.0"
#   },
#   "tagline" : "The OpenSearch Project: https://opensearch.org/"
# }

# %%
# After installation there is only one index that is the  .opendistro_security index that is used for internal purposes

# !curl -XGET "https://localhost:9200/_cat/indices?v" -u 'admin:admin' --insecure
# Out:
# health status index                uuid                   pri rep docs.count docs.deleted store.size pri.store.size
# green  open   .opendistro_security 2YfFzTEPRkWRdZQTSQui3A   1   0         10            0     68.3kb         68.3kb

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# In part 3 (step 3) we stored the mus2019ctf.plaso file in your drive. 
#
plaso_file = 'gdrive/MyDrive/mus2019ctf.plaso'
#
# and check if it's there
#
# !ls -l $plaso_file
# Out:
# -rw------- 1 root root 403488768 Aug 15 15:17 gdrive/MyDrive/mus2019ctf.plaso

# %%
# If it's not there you can create it by repeating the following steps
# 
# The complete mus2019ctf.plaso file is 450MB and takes a while. After you have created it
# it makes sense to store it in your gdrive so you can reuse it:
#
#plaso_file = 'gdrive/MyDrive/Colab\ Notebooks/Data\ Analytics\ and\ Visualisation\ Course/mus2019ctf.plaso'
#
# if not you need to create it with log2timeline.py using the complete windows_filter.txt filter
#
# add a shortcut in your Google drive to this shared drive https://drive.google.com/drive/folders/1KUlZUl4Sy2JzgbuRW-oHjIGFClY2bl75?usp=sharing
# then mount you google drive in this colab (you need to authorize this colab to access your google drive)
#
#disk_image = "/content/gdrive/MyDrive/Images/Windows/MUS-CTF-19-DESKTOP-001.E01"
#plaso_gdrive_folder = 'gdrive/MyDrive'
#!wget "https://raw.githubusercontent.com/mark-hallman/plaso_filters/master/filter_windows.txt"
#!log2timeline.py -f filter_windows.txt --storage-file mus2019ctf.plaso $disk_image 
#!ls -l $disk_image
#!cp mus2019ctf.plaso $plaso_gdrive_folder
#plaso_file = 'gdrive/MyDrive/mus2019ctf.plaso'
#!ls -l $plaso_file

# %% [markdown]
# Use psort to write events to Elasticsearch that we setup earlier. We can use the elastic output format

# %%
# run psort.py. It takes about 11-13 minutes to export all rows from the 385MB plaso file to Opensearch

#
# !psort.py -o opensearch --server localhost --port 9200 --opensearch-user admin --opensearch-password admin --opensearch_mappings /usr/share/plaso/opensearch.mappings --use_ssl --ca_certificates_file_path /content/opensearch-2.2.0/config/root-ca.pem --index_name newmus2019ctf $plaso_file --status_view none
# Out:
# 2022-08-16 18:58:49,694 [INFO] (MainProcess) PID:8576 <data_location> Determined data location: /usr/share/plaso
# 2022-08-16 18:58:50,299 [WARNING] (MainProcess) PID:8576 <opensearch_output> Note that specifying your OpenSearch password via --opensearch_password or the environment PLASO_OPENSEARCH_PASSWORD can expose the password to other users on the system.
# Processing completed.

# %%
# Let's take a look again at the indices in our Elasticsearch instance
#
#!curl -X GET "https://localhost:9200/_cat/indices?format=json&pretty" -u admin:admin --insecure
# !curl -X GET "https://localhost:9200/_cat/indices?v" -u admin:admin --insecure
# Out:
# health status index                        uuid                   pri rep docs.count docs.deleted store.size pri.store.size
# yellow open   security-auditlog-2022.08.16 VYWbw5tgQ4ykkEY6rM4vBw   1   1         40            0    168.4kb        168.4kb
# yellow open   newmus2019ctf                kgfrzDnvRZa0KZVwkfJjKw   1   1     524518            0    366.2mb        366.2mb
# green  open   .opendistro_security         2YfFzTEPRkWRdZQTSQui3A   1   0         10            0     69.1kb         69.1kb

# %%
# we can also see what fields were mapped in this index by Psort.py
#
# !curl -XGET "https://localhost:9200/newmus2019ctf/_mapping?format=json&pretty" -u admin:admin --insecure
# Out:
# {
#   "newmus2019ctf" : {
#     "mappings" : {
#       "properties" : {
#         "access_count" : {
#           "type" : "long"
#         },
#         "account_rid" : {
#           "type" : "long"
#         },
#         "application" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "binary_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "birth_droid_file_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "birth_droid_volume_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "build_number" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "cache_identifier" : {
#           "type" : "long"
#         },
#         "cached_file_size" : {
#           "type" : "long"
#         },
#         "cached_filename" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "command" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "comments" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "company_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "computer_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "configuration" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "connection_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "container_identifier" : {
#           "type" : "long"
#         },
#         "data" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "data_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "datetime" : {
#           "type" : "date"
#         },
#         "default_gateway_mac" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "description" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "device_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "directory" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "display_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "dll_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "dns_suffix" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "doc_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "drive_serial_number" : {
#           "type" : "long"
#         },
#         "drive_type" : {
#           "type" : "long"
#         },
#         "droid_file_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "droid_volume_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "entries" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "entry_identifier" : {
#           "type" : "long"
#         },
#         "entry_index" : {
#           "type" : "long"
#         },
#         "entry_number" : {
#           "type" : "long"
#         },
#         "entry_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "error_control" : {
#           "type" : "long"
#         },
#         "event_identifier" : {
#           "type" : "long"
#         },
#         "event_level" : {
#           "type" : "long"
#         },
#         "event_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "executable" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "exit_status" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "facility" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "file_attribute_flags" : {
#           "type" : "long"
#         },
#         "file_entry_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "file_reference" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "file_size" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "file_system_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "file_version" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "filename" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "flags" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "full_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "fullname" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "hostname" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "icon_location" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "image_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "imphash" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "inode" : {
#           "type" : "long"
#         },
#         "is_allocated" : {
#           "type" : "boolean"
#         },
#         "key_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "link_target" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "local_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "localized_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "login_count" : {
#           "type" : "long"
#         },
#         "long_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "mac_address" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "mapped_files" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "message" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "message_identifier" : {
#           "type" : "long"
#         },
#         "message_status" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "message_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "network_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "number_of_volumes" : {
#           "type" : "long"
#         },
#         "object_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "offset" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "origin" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "owner" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "parent_file_reference" : {
#           "type" : "long"
#         },
#         "parser" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "partition_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "partition_type" : {
#           "type" : "long"
#         },
#         "path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "path_hints" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "path_spec" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "pe_attribute" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "pe_type" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "pin_status" : {
#           "type" : "long"
#         },
#         "prefetch_hash" : {
#           "type" : "long"
#         },
#         "product" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "product_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "program_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "provider_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "record_number" : {
#           "type" : "long"
#         },
#         "recovered" : {
#           "type" : "boolean"
#         },
#         "relative_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "response_headers" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "run_count" : {
#           "type" : "long"
#         },
#         "section_names" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "sequence_number" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "serial" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "serial_number" : {
#           "type" : "long"
#         },
#         "service_dll" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "service_type" : {
#           "type" : "long"
#         },
#         "set_identifier" : {
#           "type" : "long"
#         },
#         "settings" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "severity" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "sha256_hash" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "shell_item_path" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "size" : {
#           "type" : "long"
#         },
#         "source_long" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "source_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "source_port" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "source_short" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "ssid" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "start_type" : {
#           "type" : "long"
#         },
#         "strings" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "subkey_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "sync_count" : {
#           "type" : "long"
#         },
#         "table_identifier" : {
#           "type" : "long"
#         },
#         "task_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "task_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "timestamp" : {
#           "type" : "long"
#         },
#         "timestamp_desc" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "trigger" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "update_reason_flags" : {
#           "type" : "long"
#         },
#         "update_sequence_number" : {
#           "type" : "long"
#         },
#         "update_source_flags" : {
#           "type" : "long"
#         },
#         "url" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "user_identifier" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "user_sid" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "username" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "uuid" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "value" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "value_name" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "values" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "vendor" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "version" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword"
#             }
#           }
#         },
#         "volume_device_paths" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "volume_label" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "volume_serial_numbers" : {
#           "type" : "long"
#         },
#         "working_directory" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         },
#         "xml_string" : {
#           "type" : "text",
#           "fields" : {
#             "keyword" : {
#               "type" : "keyword",
#               "ignore_above" : 256
#             }
#           }
#         }
#       }
#     }
#   }
# }

# %%
# So far we have been accessing information directly with curl from the Opensearch REST API
# The is also an Opensearch Python API that we can use. See https://opensearch.org/docs/latest/clients/python/
#

from opensearchpy import OpenSearch

host = 'localhost'
port = 9200
auth = ('admin', 'admin') # For testing only. Don't store credentials in code.
ca_certs_path = '/content/opensearch-2.2.0/config/root-ca.pem' # Provide a CA bundle if you use intermediate CAs with your root CA.

# Create the client with SSL/TLS enabled, but hostname verification disabled.
client = OpenSearch(
    hosts = [{'host': 'localhost', 'port': 9200}],
    http_compress = True, # enables gzip compression for request bodies
    http_auth = auth,
    use_ssl = True,
    verify_certs = True,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
    ca_certs = ca_certs_path
)

# %%
# We define a Python function to list results
#
def print_results(response):
  for num, doc in enumerate(response['hits']['hits']):
    print(num, '-->', doc['_source']) 

def print_results_detailed(response):
  for num, doc in enumerate(response['hits']['hits']):
    print('\n---------------------------------------------------------------------------------------------------\nresult numer: ',num) 
    for key, val in doc['_source'].items():
      print(key, val)

def print_facets(agg_dict):
  sum=0
  for field, val in agg_dict:
      print("facets of field ", field,':')
      for bucket in val['buckets']:
        for key in bucket:
          if key=='key':
            print('\t',bucket[key],end='=')
          else:
            print(bucket[key],end='')
            sum = sum + bucket[key]
        print()
      print("total number of hits for ",field," is ",sum)

def print_hit_stats(response):
  print('hit stats:')
  for key, val in response['hits'].items():
      if key=='hits' :
        print(len(val))
      else:
        print(key, val)
  print('\n')

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1 Use elasticsearch to filter events in between 2019-03-12 and 2019-03-22

# %%
# see https://opensearch.org/docs/2.0/opensearch/rest-api/search/ and find track_total_hits to get the total number of hits in stead of the max 10.000

query = '{"query": { "query_string": {"query": "datetime:[2019-03-12 TO 2019-03-22]"  }}}'

response = client.search(index="newmus2019ctf", body=query, size=0,track_total_hits=True)
print_hit_stats(response)
print_results_detailed(response)
# Out:
# hit stats:
# total {'value': 367946, 'relation': 'eq'}
# max_score None
# 0

# %% [markdown]
# ## 2 Write a query that performs an aggregation on source_long and source_short (can you find the right field names?)

# %%
query = '{"query": {"match_all": {}}, "aggs": { "source_short": { "terms": { "field": "source_short.keyword"}},  "source_long": { "terms": { "field": "source_long.keyword"}}}}'

response = client.search(index="newmus2019ctf", body=query, size=0)

print_hit_stats(response)
print_facets(response['aggregations'].items())
# Out:
# hit stats:
# total {'value': 10000, 'relation': 'gte'}
# max_score None
# 0
#
#
# facets of field  source_long :
# 	 NTFS USN change=292405
# 	 Registry Key=281913
# 	 WinEVTX=222198
# 	 File stat=3804
# 	 MSIE WebCache container record=1081
# 	 WinPrefetch=839
# 	 AppCompatCache Registry Entry=742
# 	 Registry Key - Service=588
# 	 Task Cache=537
# 	 System=257
# total number of hits for  source_long  is  804364
# facets of field  source_short :
# 	 FILE=296260
# 	 REG=283847
# 	 EVT=222198
# 	 LOG=1302
# 	 WEBHIST=1172
# 	 LNK=96
# 	 PE=86
# 	 OLECF=41
# 	 AMCACHE=8
# total number of hits for  source_short  is  1609374

# %% [markdown]
# ## 3 Combine your date range filter from exercise 1 with facet aggregation in exercise 2

# %%
querystring = '{ "query_string": {"query": "datetime:[2019-03-18 TO 2019-03-19]"  }}'
facets = '"aggs": { "source_short": { "terms": { "field": "source_short.keyword"}},  "source_long": { "terms": { "field": "source_long.keyword"}}}'
query = '{"query": %s,%s}' % (querystring,facets)
print_hit_stats(response)
response = client.search(index="newmus2019ctf", body=query, size=0)

print_facets(response['aggregations'].items())
# Out:
# hit stats:
# total {'value': 10000, 'relation': 'gte'}
# max_score None
# 0
#
#
# facets of field  source_long :
# 	 NTFS USN change=43212
# 	 WinEVTX=12808
# 	 File stat=412
# 	 MSIE WebCache container record=302
# 	 Registry Key=250
# 	 WinPrefetch=230
# 	 Task Cache=58
# 	 Background Activity Moderator Registry Entry=21
# 	 MSIE WebCache containers record=17
# 	 Windows Shortcut=17
# total number of hits for  source_long  is  57327
# facets of field  source_short :
# 	 FILE=43633
# 	 EVT=12808
# 	 REG=332
# 	 WEBHIST=319
# 	 LOG=232
# 	 LNK=17
# 	 OLECF=13
# total number of hits for  source_short  is  114681

# %% [markdown]
# ## 4 ***Advanced*** Use opensearch facet aggregation to create a treemap visualisation of a filtered set of events in the index.

# %% [markdown]
# ####Step 1
# The source_short and source_long look interesting for visualisation let's focus on REG, LOG and FILE and run a query

# %%
facets = '"aggs": {   "source_long": { "terms": { "field": "source_long.keyword"}}, "source_short": { "terms": { "field": "source_short.keyword"}}}'
daterange = 'datetime:[2019-03-12 TO 2019-03-22]'
# FILE:
querystring = '{ "query_string": {"query": "%s AND  source_short:(FILE OR LOG OR REG)"  }}' % daterange
query = '{"query": %s,%s}' % (querystring,facets)
response = client.search(index="newmus2019ctf", body=query, size=0,track_total_hits=True)
print_facets(response['aggregations'].items())
# Out:
# facets of field  source_long :
# 	 NTFS USN change=292405
# 	 Registry Key=18055
# 	 File stat=1880
# 	 WinPrefetch=597
# 	 Task Cache=158
# 	 Registry Key - Service=65
# 	 Background Activity Moderator Registry Entry=36
# 	 File entry shell item=25
# 	 Windows Setupapi Log=18
# 	 System=17
# total number of hits for  source_long  is  313256
# facets of field  source_short :
# 	 FILE=294310
# 	 REG=18335
# 	 LOG=633
# total number of hits for  source_short  is  626534

# %% [markdown]
# Why is this not very helpful for a treemap visualisation?
#
# Answer: The problem is that this breakdown is not very useful for a hierarchical visualisation like treemap or sunburst because we would like to know for each value pair (source_long, source_short) how many documents there are

# %% [markdown]
# ####Step 2
# One approach is to aggregate only accross source_long an run 3 separate queries for source_short equal to REG, LOG and FILE respectively and then combine the results into a single dataframe that we can visualise:

# %%
facets = '"aggs": {   "source_long": { "terms": { "field": "source_long.keyword"}}}'
daterange = 'datetime:[2019-03-12 TO 2019-03-22]'
# FILE:
querystring_file = '{ "query_string": {"query": "%s AND  source_short:FILE"  }}' % daterange
query_file = '{"query": %s,%s}' % (querystring_file,facets)
# LOG:
querystring_log = '{ "query_string": {"query": "%s AND  source_short:LOG"  }}' % daterange
query_log = '{"query": %s,%s}' % (querystring_log,facets)
# REG
querystring_reg = '{ "query_string": {"query": "%s AND  source_short:REG"  }}' % daterange
query_reg = '{"query": %s,%s}' % (querystring_reg,facets)


response_reg = client.search(index="newmus2019ctf", body=query_reg, size=0,track_total_hits=True)
response_file = client.search(index="newmus2019ctf", body=query_file, size=0,track_total_hits=True)
response_log = client.search(index="newmus2019ctf", body=query_log, size=0,track_total_hits=True)


print('Facets for REG:')
print_facets(response_reg['aggregations'].items())

print('Facet for FILE:')
print_facets(response_file['aggregations'].items())

print('Facets for LOG:')
print_facets(response_log['aggregations'].items())
# Out:
# Facets for REG:
# facets of field  source_long :
# 	 Registry Key=18055
# 	 Task Cache=158
# 	 Registry Key - Service=65
# 	 Background Activity Moderator Registry Entry=36
# 	 AppCompatCache Registry Entry=13
# 	 Registry Key - Winlogon=3
# 	 Registry Key - USB Entries=2
# 	 Registry Key - Run Key=1
# 	 Registry Key - User Account Information=1
# 	 Registry Key Shutdown Entry=1
# total number of hits for  source_long  is  18335
# Facet for FILE:
# facets of field  source_long :
# 	 NTFS USN change=292405
# 	 File stat=1880
# 	 File entry shell item=25
# total number of hits for  source_long  is  294310
# Facets for LOG:
# facets of field  source_long :
# 	 WinPrefetch=597
# 	 Windows Setupapi Log=18
# 	 System=17
# 	 System - Network Connection=1
# total number of hits for  source_long  is  633

# %%
# create a variation of the print_facets function that outputs values to a list
# containing source_short, source_long and doc_count
# 
def buckets_to_list(agg_dict,source_short,list):
  for field, val in agg_dict:
    for bucket in val['buckets']:
      list.append([source_short,bucket['key'],bucket['doc_count']])
  return list
  
data1 = []
buckets_to_list(response_file['aggregations'].items(),'FILE',data1)
buckets_to_list(response_reg['aggregations'].items(),'REG',data1)
buckets_to_list(response_log['aggregations'].items(),'LOG',data1)

data1
# Out:
# [['FILE', 'NTFS USN change', 292405],
#  ['FILE', 'File stat', 1880],
#  ['FILE', 'File entry shell item', 25],
#  ['REG', 'Registry Key', 18055],
#  ['REG', 'Task Cache', 158],
#  ['REG', 'Registry Key - Service', 65],
#  ['REG', 'Background Activity Moderator Registry Entry', 36],
#  ['REG', 'AppCompatCache Registry Entry', 13],
#  ['REG', 'Registry Key - Winlogon', 3],
#  ['REG', 'Registry Key - USB Entries', 2],
#  ['REG', 'Registry Key - Run Key', 1],
#  ['REG', 'Registry Key - User Account Information', 1],
#  ['REG', 'Registry Key Shutdown Entry', 1],
#  ['LOG', 'WinPrefetch', 597],
#  ['LOG', 'Windows Setupapi Log', 18],
#  ['LOG', 'System', 17],
#  ['LOG', 'System - Network Connection', 1]]

# %%
df1 = pd.DataFrame(data1)
df1
# Out:
#        0                                             1       2
# 0   FILE                               NTFS USN change  292405
# 1   FILE                                     File stat    1880
# 2   FILE                         File entry shell item      25
# 3    REG                                  Registry Key   18055
# 4    REG                                    Task Cache     158
# 5    REG                        Registry Key - Service      65
# 6    REG  Background Activity Moderator Registry Entry      36
# 7    REG                 AppCompatCache Registry Entry      13
# 8    REG                       Registry Key - Winlogon       3
# 9    REG                    Registry Key - USB Entries       2
# 10   REG                        Registry Key - Run Key       1
# 11   REG       Registry Key - User Account Information       1
# 12   REG                   Registry Key Shutdown Entry       1
# 13   LOG                                   WinPrefetch     597
# 14   LOG                          Windows Setupapi Log      18
# 15   LOG                                        System      17
# 16   LOG                   System - Network Connection       1

# %%
# set column names

df1.columns = ['source_short','source_long','count']
df1
# Out:
#    source_short                                   source_long   count
# 0          FILE                               NTFS USN change  292405
# 1          FILE                                     File stat    1880
# 2          FILE                         File entry shell item      25
# 3           REG                                  Registry Key   18055
# 4           REG                                    Task Cache     158
# 5           REG                        Registry Key - Service      65
# 6           REG  Background Activity Moderator Registry Entry      36
# 7           REG                 AppCompatCache Registry Entry      13
# 8           REG                       Registry Key - Winlogon       3
# 9           REG                    Registry Key - USB Entries       2
# 10          REG                        Registry Key - Run Key       1
# 11          REG       Registry Key - User Account Information       1
# 12          REG                   Registry Key Shutdown Entry       1
# 13          LOG                                   WinPrefetch     597
# 14          LOG                          Windows Setupapi Log      18
# 15          LOG                                        System      17
# 16          LOG                   System - Network Connection       1

# %%
# !pip install --upgrade plotly

import plotly.express as px
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Collecting plotly
#   Downloading plotly-5.10.0-py2.py3-none-any.whl (15.2 MB)
#      |████████████████████████████████| 15.2 MB 5.2 MB/s
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# Successfully installed plotly-5.10.0

# %%
fig = px.treemap(df1, path=['source_short', 'source_long'],values='count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="3973cb3f-7595-4981-89b2-64218d9e3a58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3973cb3f-7595-4981-89b2-64218d9e3a58")) {                    Plotly.newPlot(                        "3973cb3f-7595-4981-89b2-64218d9e3a58",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["REG/AppCompatCache Registry Entry","REG/Background Activity Moderator Registry Entry","FILE/File entry shell item","FILE/File stat","FILE/NTFS USN change","REG/Registry Key","REG/Registry Key - Run Key","REG/Registry Key - Service","REG/Registry Key - USB Entries","REG/Registry Key - User Account Information","REG/Registry Key - Winlogon","REG/Registry Key Shutdown Entry","LOG/System","LOG/System - Network Connection","REG/Task Cache","LOG/WinPrefetch","LOG/Windows Setupapi Log","FILE","LOG","REG"],"labels":["AppCompatCache Registry Entry","Background Activity Moderator Registry Entry","File entry shell item","File stat","NTFS USN change","Registry Key","Registry Key - Run Key","Registry Key - Service","Registry Key - USB Entries","Registry Key - User Account Information","Registry Key - Winlogon","Registry Key Shutdown Entry","System","System - Network Connection","Task Cache","WinPrefetch","Windows Setupapi Log","FILE","LOG","REG"],"name":"","parents":["REG","REG","FILE","FILE","FILE","REG","REG","REG","REG","REG","REG","REG","LOG","LOG","REG","LOG","LOG","","",""],"values":[13,36,25,1880,292405,18055,1,65,2,1,3,1,17,1,158,597,18,294310,633,18335],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type": ...

# %% [markdown]
# This was a bit cumbersome approach. In step 3 we'll improve and show a way how to do this with a single opensearch query

# %% [markdown]
# ####Step 3
# Opensearch can also aggregate accros multiple fields combined. This is called multi_terms aggregation which aggregates accross all (source_long, source_short) value pairs. Note: by default opensearch returns 10 buckets max. We set it to 20 here using the size parameter.
#
# See https://opensearch.org/docs/2.0/opensearch/bucket-agg/ for more information about opensearch and multi_term aggregation.

# %%
facets = '"aggs": {   "source_long_short": { "multi_terms": { "terms": [{ "field": "source_long.keyword"},{"field": "source_short.keyword"}], "size":20}}}'
daterange = 'datetime:[2019-03-12 TO 2019-03-22]'
# FILE:
querystring = '{ "query_string": {"query": "%s AND  source_short:(FILE OR LOG OR REG)"  }}' % daterange
query = '{"query": %s,%s}' % (querystring,facets)

response = client.search(index="newmus2019ctf", body=query, size=0,track_total_hits=True)
response
# Out:
# {'took': 5,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 313278, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'source_long_short': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': ['NTFS USN change', 'FILE'],
#      'key_as_string': 'NTFS USN change|FILE',
#      'doc_count': 292405},
#     {'key': ['Registry Key', 'REG'],
#      'key_as_string': 'Registry Key|REG',
#      'doc_count': 18055},
#     {'key': ['File stat', 'FILE'],
#      'key_as_string': 'File stat|FILE',
#      'doc_count': 1880},
#     {'key': ['WinPrefetch', 'LOG'],
#      'key_as_string': 'WinPrefetch|LOG',
#      'doc_count': 597},
#     {'key': ['Task Cache', 'REG'],
#      'key_as_string': 'Task Cache|REG',
#      'doc_count': 158},
#     {'key': ['Registry Key - Service', 'REG'],
#      'key_as_string': 'Registry Key - Service|REG',
#      'doc_count': 65},
#     {'key': ['Background Activity Moderator Registry Entry', 'REG'],
#      'key_as_string': 'Background Activity Moderator Registry Entry|REG',
#      'doc_count': 36},
#     {'key': ['File entry shell item', 'FILE'],
#      'key_as_string': 'File entry shell item|FILE',
#      'doc_count': 25},
#     {'key': ['Windows Setupapi Log', 'LOG'],
#      'key_as_string': 'Windows Setupapi Log|LOG',
#      'doc_count': 18},
#     {'key': ['System', 'LOG'], 'key_as_string': 'System|LOG', 'doc_count': 17},
#     {'key': ['AppCompatCache Registry Entry', 'REG'],
#      'key_as_string': 'AppCompatCache Registry Entry|REG',
#      'doc_count': 13},
#     {'key': ['Registry Key - Winlogon', 'REG'],
#      'key_as_string': 'Registry Key - Winlogon|REG',
#      'doc_count': 3},
#     {'key': ['Registry Key - USB Entries', 'REG'],
#      'key_as_string': 'Registry Key - USB Entries|REG',
#      'doc_count': 2},
#     {'key': ['Registry Key - Run Key', 'REG'],
#      'key_as_string': 'Registry Key - Run Key|REG',
#      'doc_count': 1},
#     {'key': ['Registry Key - User Account Information', 'REG'],
#      'key_as_string': 'Registry Key - User Account Information|REG',
#      'doc_count': 1},
#     {'key': ['Registry Key Shutdown Entry', 'REG'],
#      'key_as_string': 'Registry Key Shutdown Entry|REG',
#      'doc_count': 1},
#     {'key': ['System - Network Connection', 'LOG'],
#      'key_as_string': 'System - Network Connection|LOG',
#      'doc_count': 1}]}}}

# %%
# we need to redefine our bucket to list function

def buckets_to_list2(agg_dict):
  list = []
  for field, val in agg_dict:
    for bucket in val['buckets']:
      list.append([bucket['key'][1],bucket['key'][0],bucket['doc_count']])
  return list


data2 = buckets_to_list2(response['aggregations'].items())

# %%
data2
# Out:
# [['FILE', 'NTFS USN change', 292405],
#  ['REG', 'Registry Key', 18055],
#  ['FILE', 'File stat', 1880],
#  ['LOG', 'WinPrefetch', 597],
#  ['REG', 'Task Cache', 158],
#  ['REG', 'Registry Key - Service', 65],
#  ['REG', 'Background Activity Moderator Registry Entry', 36],
#  ['FILE', 'File entry shell item', 25],
#  ['LOG', 'Windows Setupapi Log', 18],
#  ['LOG', 'System', 17],
#  ['REG', 'AppCompatCache Registry Entry', 13],
#  ['REG', 'Registry Key - Winlogon', 3],
#  ['REG', 'Registry Key - USB Entries', 2],
#  ['REG', 'Registry Key - Run Key', 1],
#  ['REG', 'Registry Key - User Account Information', 1],
#  ['REG', 'Registry Key Shutdown Entry', 1],
#  ['LOG', 'System - Network Connection', 1]]

# %%
df2 = pd.DataFrame(data2)
df2.columns = ['source_short','source_long','count']
df2
# Out:
#    source_short                                   source_long   count
# 0          FILE                               NTFS USN change  292405
# 1           REG                                  Registry Key   18055
# 2          FILE                                     File stat    1880
# 3           LOG                                   WinPrefetch     597
# 4           REG                                    Task Cache     158
# 5           REG                        Registry Key - Service      65
# 6           REG  Background Activity Moderator Registry Entry      36
# 7          FILE                         File entry shell item      25
# 8           LOG                          Windows Setupapi Log      18
# 9           LOG                                        System      17
# 10          REG                 AppCompatCache Registry Entry      13
# 11          REG                       Registry Key - Winlogon       3
# 12          REG                    Registry Key - USB Entries       2
# 13          REG                        Registry Key - Run Key       1
# 14          REG       Registry Key - User Account Information       1
# 15          REG                   Registry Key Shutdown Entry       1
# 16          LOG                   System - Network Connection       1

# %%
fig = px.treemap(df2, path=['source_short', 'source_long'],values='count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="759be614-3304-4e54-9aef-6f665f9033b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("759be614-3304-4e54-9aef-6f665f9033b1")) {                    Plotly.newPlot(                        "759be614-3304-4e54-9aef-6f665f9033b1",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["REG/AppCompatCache Registry Entry","REG/Background Activity Moderator Registry Entry","FILE/File entry shell item","FILE/File stat","FILE/NTFS USN change","REG/Registry Key","REG/Registry Key - Run Key","REG/Registry Key - Service","REG/Registry Key - USB Entries","REG/Registry Key - User Account Information","REG/Registry Key - Winlogon","REG/Registry Key Shutdown Entry","LOG/System","LOG/System - Network Connection","REG/Task Cache","LOG/WinPrefetch","LOG/Windows Setupapi Log","FILE","LOG","REG"],"labels":["AppCompatCache Registry Entry","Background Activity Moderator Registry Entry","File entry shell item","File stat","NTFS USN change","Registry Key","Registry Key - Run Key","Registry Key - Service","Registry Key - USB Entries","Registry Key - User Account Information","Registry Key - Winlogon","Registry Key Shutdown Entry","System","System - Network Connection","Task Cache","WinPrefetch","Windows Setupapi Log","FILE","LOG","REG"],"name":"","parents":["REG","REG","FILE","FILE","FILE","REG","REG","REG","REG","REG","REG","REG","LOG","LOG","REG","LOG","LOG","","",""],"values":[13,36,25,1880,292405,18055,1,65,2,1,3,1,17,1,158,597,18,294310,633,18335],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type": ...

# %% [markdown]
# So we have the same result as under step 2 but we only needed one query by using multi_term aggregation.

# %% [markdown]
# ####Step 4
# The exercise asked for aggregation accross 3 fields. So let's add the parser field and deepen our treemap visualisation

# %%
facets = '"aggs": {   "source_long_short": { "multi_terms": { "terms": [{ "field": "source_long.keyword"},{"field": "source_short.keyword"},{ "field": "parser.keyword"}], "size":200}}}'
daterange = 'datetime:[2019-03-12 TO 2019-03-22]'
# FILE:
querystring = '{ "query_string": {"query": "%s "  }}' % daterange
query = '{"query": %s,%s}' % (querystring,facets)

response3 = client.search(index="newmus2019ctf", body=query, size=0,track_total_hits=True)
response3
# Out:
# {'took': 9,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 367946, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'source_long_short': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': ['NTFS USN change', 'FILE', 'usnjrnl'],
#      'key_as_string': 'NTFS USN change|FILE|usnjrnl',
#      'doc_count': 292405},
#     {'key': ['WinEVTX', 'EVT', 'winevtx'],
#      'key_as_string': 'WinEVTX|EVT|winevtx',
#      'doc_count': 54118},
#     {'key': ['Registry Key', 'REG', 'winreg/winreg_default'],
#      'key_as_string': 'Registry Key|REG|winreg/winreg_default',
#      'doc_count': 17919},
#     {'key': ['File stat', 'FILE', 'filestat'],
#      'key_as_string': 'File stat|FILE|filestat',
#      'doc_count': 1880},
#     {'key': ['WinPrefetch', 'LOG', 'prefetch'],
#      'key_as_string': 'WinPrefetch|LOG|prefetch',
#      'doc_count': 597},
#     {'key': ['MSIE WebCache container record',
#       'WEBHIST',
#       'esedb/msie_webcache'],
#      'key_as_string': 'MSIE WebCache container record|WEBHIST|esedb/msie_webcache',
#      'doc_count': 435},
#     {'key': ['Task Cache', 'REG', 'winreg/windows_task_cache'],
#      'key_as_string': 'Task Cache|REG|winreg/windows_task_cache',
#      'doc_count': 158},
#     {'key': ['Registry Key', 'REG', 'winreg/amcache'],
#      'key_as_string': 'Registry Key|REG|winreg/amcache',
#      'doc_count': 131},
#     {'key': ['Registry Key - Service', 'REG', 'winreg/windows_services'],
#      'key_as_string': 'Registry Key - Service|REG|winreg/windows_services',
#      'doc_count': 65},
#     {'key': ['MSIE WebCache containers record',
#       'WEBHIST',
#       'esedb/msie_webcache'],
#      'key_as_string': 'MSIE WebCache containers record|WEBHIST|esedb/msie_webcache',
#      'doc_count': 37},
#     {'key': ['Background Activity Moderator Registry Entry',
#       'REG',
#       'winreg/bam'],
#      'key_as_string': 'Background Activity Moderator Registry Entry|REG|winreg/bam',
#      'doc_count': 36},
#     {'key': ['Windows Shortcut',
#       'LNK',
#       'olecf/olecf_automatic_destinations/lnk'],
#      'key_as_string': 'Windows Shortcut|LNK|olecf/olecf_automatic_destinations/lnk',
#      'doc_count': 23},
#     {'key': ['MSIE WebCache partitions record',
#       'WEBHIST',
#       'esedb/msie_webcache'],
#      'key_as_string': 'MSIE WebCache partitions record|WEBHIST|esedb/msie_webcache',
#      'doc_count': 18},
#     {'key': ['Windows Setupapi Log', 'LOG', 'setupapi'],
#      'key_as_string': 'Windows Setupapi Log|LOG|setupapi',
#      'doc_count': 18},
#     {'key': ['File entry shell item',
#       'FILE',
#       'olecf/olecf_automatic_destinations/lnk/shell_items'],
#      'key_as_string': 'File entry shell item|FILE|olecf/olecf_automatic_destinations/lnk/shell_items',
#      'doc_count': 17},
#     {'key': ['OLECF Dest list entry',
#       'OLECF',
#       'olecf/olecf_automatic_destinations'],
#      'key_as_string': 'OLECF Dest list entry|OLECF|olecf/olecf_automatic_destinations',
#      'doc_count': 15},
#     {'key': ['Windows Shortcut', 'LNK', 'lnk'],
#      'key_as_string': 'Windows Shortcut|LNK|lnk',
#      'doc_count': 14},
#     {'key': ['AppCompatCache Registry Entry', 'REG', 'winreg/appcompatcache'],
#      'key_as_string': 'AppCompatCache Registry Entry|REG|winreg/appcompatcache',
#      'doc_count': 13},
#     {'key': ['File entry shell item', 'FILE', 'lnk/shell_items'],
#      'key_as_string': 'File entry shell item|FILE|lnk/shell_items',
#      'doc_count': 8},
#     {'key': ['OLECF Item', 'OLECF', 'olecf/olecf_default'],
#      'key_as_string': 'OLECF Item|OLECF|olecf/olecf_default',
#      'doc_count': 8},
#     {'key': ['System', 'LOG', 'olecf/olecf_automatic_destinations'],
#      'key_as_string': 'System|LOG|olecf/olecf_automatic_destinations',
#      'doc_count': 6},
#     {'key': ['System', 'LOG', 'olecf/olecf_automatic_destinations/lnk'],
#      'key_as_string': 'System|LOG|olecf/olecf_automatic_destinations/lnk',
#      'doc_count': 6},
#     {'key': ['System', 'LOG', 'lnk'],
#      'key_as_string': 'System|LOG|lnk',
#      'doc_count': 5},
#     {'key': ['Registry Key - Winlogon', 'REG', 'winreg/winlogon'],
#      'key_as_string': 'Registry Key - Winlogon|REG|winreg/winlogon',
#      'doc_count': 3},
#     {'key': ['Registry Key', 'REG', 'winreg/windows_boot_execute'],
#      'key_as_string': 'Registry Key|REG|winreg/windows_boot_execute',
#      'doc_count': 2},
#     {'key': ['Registry Key', 'REG', 'winreg/windows_version'],
#      'key_as_string': 'Registry Key|REG|winreg/windows_version',
#      'doc_count': 2},
#     {'key': ['Registry Key - USB Entries',
#       'REG',
#       'winreg/windows_usb_devices'],
#      'key_as_string': 'Registry Key - USB Entries|REG|winreg/windows_usb_devices',
#      'doc_count': 2},
#     {'key': ['Registry Key', 'REG', 'winreg/windows_shutdown'],
#      'key_as_string': 'Registry Key|REG|winreg/windows_shutdown',
#      'doc_count': 1},
#     {'key': ['Registry Key - Run Key', 'REG', 'winreg/windows_run'],
#      'key_as_string': 'Registry Key - Run Key|REG|winreg/windows_run',
#      'doc_count': 1},
#     {'key': ['Registry Key - User Account Information',
#       'REG',
#       'winreg/windows_sam_users'],
#      'key_as_string': 'Registry Key - User Account Information|REG|winreg/windows_sam_users',
#      'doc_count': 1},
#     {'key': ['Registry Key Shutdown Entry', 'REG', 'winreg/windows_shutdown'],
#      'key_as_string': 'Registry Key Shutdown Entry|REG|winreg/windows_shutdown',
#      'doc_count': 1},
#     {'key': ['System - Network Connection', 'LOG', 'winreg/networks'],
#      'key_as_string': 'System - Network Connection|LOG|winreg/networks',
#      'doc_count': 1}]}}}

# %%
def buckets_to_list3(agg_dict):
  list = []
  for field, val in agg_dict:
    for bucket in val['buckets']:
      list.append([bucket['key'][2],bucket['key'][1],bucket['key'][0],bucket['doc_count']])
  return list


data3 = buckets_to_list3(response3['aggregations'].items())
data3
# Out:
# [['usnjrnl', 'FILE', 'NTFS USN change', 292405],
#  ['winevtx', 'EVT', 'WinEVTX', 54118],
#  ['winreg/winreg_default', 'REG', 'Registry Key', 17919],
#  ['filestat', 'FILE', 'File stat', 1880],
#  ['prefetch', 'LOG', 'WinPrefetch', 597],
#  ['esedb/msie_webcache', 'WEBHIST', 'MSIE WebCache container record', 435],
#  ['winreg/windows_task_cache', 'REG', 'Task Cache', 158],
#  ['winreg/amcache', 'REG', 'Registry Key', 131],
#  ['winreg/windows_services', 'REG', 'Registry Key - Service', 65],
#  ['esedb/msie_webcache', 'WEBHIST', 'MSIE WebCache containers record', 37],
#  ['winreg/bam', 'REG', 'Background Activity Moderator Registry Entry', 36],
#  ['olecf/olecf_automatic_destinations/lnk', 'LNK', 'Windows Shortcut', 23],
#  ['esedb/msie_webcache', 'WEBHIST', 'MSIE WebCache partitions record', 18],
#  ['setupapi', 'LOG', 'Windows Setupapi Log', 18],
#  ['olecf/olecf_automatic_destinations/lnk/shell_items',
#   'FILE',
#   'File entry shell item',
#   17],
#  ['olecf/olecf_automatic_destinations', 'OLECF', 'OLECF Dest list entry', 15],
#  ['lnk', 'LNK', 'Windows Shortcut', 14],
#  ['winreg/appcompatcache', 'REG', 'AppCompatCache Registry Entry', 13],
#  ['lnk/shell_items', 'FILE', 'File entry shell item', 8],
#  ['olecf/olecf_default', 'OLECF', 'OLECF Item', 8],
#  ['olecf/olecf_automatic_destinations', 'LOG', 'System', 6],
#  ['olecf/olecf_automatic_destinations/lnk', 'LOG', 'System', 6],
#  ['lnk', 'LOG', 'System', 5],
#  ['winreg/winlogon', 'REG', 'Registry Key - Winlogon', 3],
#  ['winreg/windows_boot_execute', 'REG', 'Registry Key', 2],
#  ['winreg/windows_version', 'REG', 'Registry Key', 2],
#  ['winreg/windows_usb_devices', 'REG', 'Registry Key - USB Entries', 2],
#  ['winreg/windows_shutdown', 'REG', 'Registry Key', 1],
#  ['winreg/windows_run', 'REG', 'Registry Key - Run Key', 1],
#  ['winreg/windows_sam_users',
#   'REG',
#   'Registry Key - User Account Information',
#   1],
#  ['winreg/windows_shutdown', 'REG', 'Registry Key Shutdown Entry', 1],
#  ['winreg/networks', 'LOG', 'System - Network Connection', 1]]

# %%
df3 = pd.DataFrame(data3)
df3.columns = ['parser','source_short','source_long','count']
df3
# Out:
#                                                parser source_short  \
# 0                                             usnjrnl         FILE
# 1                                             winevtx          EVT
# 2                               winreg/winreg_default          REG
# 3                                            filestat         FILE
# 4                                            prefetch          LOG
# 5                                 esedb/msie_webcache      WEBHIST
# 6                           winreg/windows_task_cache          REG
# 7                                      winreg/amcache          REG
# 8                             winreg/windows_services          REG
# 9                                 esedb/msie_webcache      WEBHIST
# 10                                         winreg/bam          REG
# 11             olecf/olecf_automatic_destinations/lnk          LNK
# 12                                esedb/msie_webcache      WEBHIST
# 13                                           setupapi          LOG
# 14  olecf/olecf_automatic_destinations/lnk/shell_i...         FILE
# 15                 olecf/olecf_automatic_destinations        OLECF
# 16                                                lnk          LNK
# 17                              winreg/appcompatcache          REG
# 18                                    lnk/shell_items         FILE
# 19                                olecf/olecf_default        OLECF
# 20                 olecf/olecf_automatic_destinations          LOG
# 21             olecf/olecf_automatic_destinations/lnk          LOG
# 22                                                lnk          LOG
# 23                                    winreg/winlogon          REG
# 24                        winreg/windows_boot_execute          REG
# 25                             winreg/windows_version          REG
# 26                         winreg/windows_usb_devices          REG
# 27                            winreg/windows_shutdown          REG
# 28                                 winreg/windows_run          REG
# 29                           winreg/windows_sam_users          REG
# 30                            winreg/windows_shutdown          REG
# 31                                    winreg/networks          LOG
#
#                                      source_long   count
# 0                                NTFS USN change  292405
# 1                                        WinEVTX   54118
# 2                                   Registry Key   17919
# 3                                      File stat    1880
# 4                                    WinPrefetch     597
# 5                 MSIE WebCache container record     435
# 6                                     Task Cache     158
# 7                                   Registry Key     131
# 8                         Registry Key - Service      65
# 9                MSIE WebCache containers record      37
# 10  Background Activity Moderator Registry Entry      36
# 11                              Windows Shortcut      23
# 12               MSIE WebCache partitions record      18
# 13                          Windows Setupapi Log      18
# 14                         File entry shell item      17
# 15                         OLECF Dest list entry      15
# 16                              Windows Shortcut      14
# 17                 AppCompatCache Registry Entry      13
# 18                         File entry shell item       8
# 19                                    OLECF Item       8
# 20                                        System       6
# 21                                        System       6
# 22                                        System       5
# 23                       Registry Key - Winlogon       3
# 24                                  Registry Key       2
# 25                                  Registry Key       2
# 26                    Registry Key - USB Entries       2
# 27                                  Registry Key       1
# 28                        Registry Key - Run Key       1
# 29       Registry Key - User Account Information       1
# 30                   Registry Key Shutdown Entry       1
# 31                   System - Network Connection       1

# %%
fig = px.treemap(df3, path=['parser','source_short', 'source_long'],values='count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="d3a0294e-dc27-47ac-a55f-7fe5c9b0d95b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3a0294e-dc27-47ac-a55f-7fe5c9b0d95b")) {                    Plotly.newPlot(                        "d3a0294e-dc27-47ac-a55f-7fe5c9b0d95b",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["winreg/appcompatcache/REG/AppCompatCache Registry Entry","winreg/bam/REG/Background Activity Moderator Registry Entry","lnk/shell_items/FILE/File entry shell item","olecf/olecf_automatic_destinations/lnk/shell_items/FILE/File entry shell item","filestat/FILE/File stat","esedb/msie_webcache/WEBHIST/MSIE WebCache container record","esedb/msie_webcache/WEBHIST/MSIE WebCache containers record","esedb/msie_webcache/WEBHIST/MSIE WebCache partitions record","usnjrnl/FILE/NTFS USN change","olecf/olecf_automatic_destinations/OLECF/OLECF Dest list entry","olecf/olecf_default/OLECF/OLECF Item","winreg/amcache/REG/Registry Key","winreg/windows_boot_execute/REG/Registry Key","winreg/windows_shutdown/REG/Registry Key","winreg/windows_version/REG/Registry Key","winreg/winreg_default/REG/Registry Key","winreg/windows_run/REG/Registry Key - Run Key","winreg/windows_services/REG/Registry Key - Service","winreg/windows_usb_devices/REG/Registry Key - USB Entries","winreg/windows_sam_users/REG/Registry Key - User Account Information","winreg/winlogon/REG/Registry Key - Winlogon","winreg/windows_shutdown/REG/Registry Key Shutdown Entry","lnk/LOG/System","olecf/olecf_automatic_destinations/LOG/System","olecf/olecf_automatic_destinations/lnk/LOG/System","winreg/networks/LOG/System - Network Connection","winreg/windows_task_cache/REG/Task Cache","winevtx/EVT/WinEVTX","prefetch/LOG/WinPrefetch","setupapi/LOG/Windows Setupapi Log","lnk/LNK/Windows Shortcut","olecf/olecf_automatic_destinations/lnk/LNK/Windows Shortcut","winevtx/EVT","filestat/FILE","lnk/shell_items/FILE","olecf/olecf_automatic_destinations/lnk/shell_items/FILE","usnjrnl/FILE","lnk/LNK","olecf/olecf_automatic_destinations/lnk/LNK","lnk/LOG","olecf/olecf_automatic_destinations/LOG","olecf/olecf_automatic_destinations/lnk/LOG","prefetch/LOG","setupapi/LOG","winreg/networks/LOG","olecf/olecf_automatic_destinations/OLECF","olecf/olecf_default/OLECF","winreg/amcache/REG","winreg/appcompatcache/REG","winreg/bam/REG","winreg/windows_boot_execute/REG","winreg/windows_run/REG","winreg/windows_sam_users/REG","winreg/windows_services/REG","winreg/windows_shutdown/REG","winreg/windows_task_cache/REG","winreg/windows_usb_devices/REG","winreg/windows_version/REG","winreg/winlogon/REG","winreg/winreg_default/REG","esedb/msie_webcache/WEBHIST","esedb/msie_webcache","filestat","lnk","lnk/shell_items","olecf/olecf_automatic_destinations","olecf/olecf_automatic_destinations/lnk","olecf/olecf_automatic_destinations/lnk/shell_items","olecf/olecf_default","prefetch","setupapi","usnjrnl","winevtx","winreg/amcache","winreg/appcompatcache","winreg/bam","winreg/networks","winreg/windows_boot_execute","winreg/windows_run","winreg/windows_sam_users","winreg/windows_services","winreg/windows_shutdown","winreg/windows_task_cache","winreg/windows_usb_devices","winreg/windows_version","winreg/winlogon","winreg/winreg_default"],"labels":["AppCompatCache Registry Entry","Background Activity Moderator Registry Entry","File entry shell item","File entry shell item","File stat","MSIE WebCache container record","MSIE WebCache containers record","MSIE WebCache partitions record","NTFS USN change","OLECF Dest list entry","OLECF Item","Registry Key","Registry Key","Registry Key","Registry Key","Registry Key","Registry Key -  ...
